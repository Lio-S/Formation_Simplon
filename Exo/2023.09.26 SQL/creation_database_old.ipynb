# %%
pip install mysql-connector-python

# %%
import mysql.connector

# Remplacez les valeurs suivantes par les informations de connexion à votre serveur MySQL
host = "localhost" # L'hôte du serveur MySQL
user = "root"  # Votre nom d'utilisateur MySQL
password = "root"  # Votre mot de passe MySQL
database_name = "courses"  # Le nom de la nouvelle base de données



# Créez une connexion au serveur MySQL
conn = mysql.connector.connect(
    host=host,
    user=user,
    password=password
)

# Créez un curseur pour exécuter des requêtes SQL
cursor = conn.cursor()

# Exécutez une requête SQL pour obtenir la liste des bases de données
cursor.execute("SHOW DATABASES")

# Récupérez les résultats de la requête
databases = cursor.fetchall()

# Vérifiez si la base de données que vous recherchez existe
if (database_name,) in databases:
    print(f"La base de données '{database_name}' existe.")
else:
    print(f"La base de données '{database_name}' n'existe pas.")
     # Utilisez le curseur pour exécuter une commande SQL de création de base de données
    create_database_query = f"CREATE DATABASE {database_name}"
    cursor.execute(create_database_query)
    print(f"La base de données '{database_name}' a été créée avec succès.")

# Fermez le curseur et la connexion
cursor.close()
conn.close()

# %%
import csv

# %%
# Chemin vers le fichier CSV
csv_file_path = "Produits_-_Feuille_1.csv"

# Établir une connexion à la base de données
conn = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database_name
)

# Créer un curseur pour exécuter des requêtes SQL
cursor = conn.cursor(buffered=True)

# Lecture du fichier CSV et insertion des données dans la table
with open(csv_file_path, "r", newline="") as csv_file:
    csv_reader = csv.reader(csv_file)
    en_tetes = next(csv_reader) # Enregistrer et Ignorer la première ligne si elle contient les en-têtes
    csv_reader = list(csv_reader)

for row in csv_reader:

    # Insérer les données dans la table MySQL
    insert_conditions = "INSERT IGNORE INTO courses.conditions (contenant_produit) VALUES (%s)"
    # Remplacez "nom_de_la_table" et les colonnes par les valeurs appropriées

    # Exécution de la requête d'insertion
    cursor.execute(insert_conditions, (row[3],))

    # Insérer les données dans la table MySQL
    insert_famille_article = "INSERT IGNORE INTO courses.famille_article (famille_produit) VALUES (%s)"
    # Remplacez "nom_de_la_table" et les colonnes par les valeurs appropriées

    # Exécution de la requête d'insertion
    cursor.execute(insert_famille_article, (row[2],))

    select_id_condition = f"SELECT id FROM conditions WHERE contenant_produit = %s"

    cursor.execute(select_id_condition, (row[3],))

    conditions_id = cursor.fetchone()[0]

    # Vide le curseur
    cursor.fetchone() 

    select_id_famille_article = f"SELECT id FROM famille_article WHERE famille_produit = %s"

    cursor.execute(select_id_famille_article, (row[2],))

    famille_article_id = cursor.fetchone()[0]

    cursor.fetchone()
    
    # Insérer les données dans la table MySQL
    insert_produit = "INSERT INTO courses.produit (code_article, libelle_article, famille_article_id, condition_id, pu_ht) VALUES (%s, %s, %s, %s, %s)"
    # Remplacez "nom_de_la_table" et les colonnes par les valeurs appropriées

    # Exécution de la requête d'insertion
    cursor.execute(insert_produit, (row[0],row[1],famille_article_id,conditions_id,row[4]))

# Valider les modifications dans la base de données
conn.commit()

# Fermer le curseur et la connexion
cursor.close()
conn.close()

print("Les données du fichier CSV ont été insérées avec succès dans la base de données.")

# %%
import pandas as pd

# %%
# Lecture Base
import mysql.connector

# Remplacez les valeurs suivantes par les informations de connexion à votre serveur MySQL
host = "localhost" # L'hôte du serveur MySQL
user = "root"  # Votre nom d'utilisateur MySQL
password = "root"  # Votre mot de passe MySQL
database_name = "courses"  # Le nom de la nouvelle base de données

# help(cursor.execute)

# Établir une connexion à la base de données
conn = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database_name
)

# Créer un curseur pour exécuter des requêtes SQL
cursor = conn.cursor(buffered=True)     # "Buffered = True" pour l'auto fermeture

# Lire les données dans la table MySQL produit
select_id_condition = f"SELECT * FROM produit"

# Exécution de la requête d'insertion
cursor.execute(select_id_condition)
Info_Recuperees = cursor.fetchall()

# Valider les modifications dans la base de données
conn.commit()

# Fermer le curseur et la connexion
cursor.close()
conn.close()

(Info_Recuperees)
# Out:
# [(1, 1010, 'HUILE ARACHIDE 25 L', 2, 2, 60.71),
#  (2, 1011, 'HUILE ARACHIDE 5 L', 2, 2, 14.33),
#  (3, 1012, 'HUILE ARACHIDE 1 L', 2, 4, 2.87),
#  (4, 1014, 'HUILE MEZZO 1 L (50%OLIVE50%TOURNESOL)', 2, 4, 2.67),
#  (5, 1015, 'HUILE COLZA 5 L', 2, 2, 7.57),
#  (6, 1016, 'HUILE COLZA 1 L', 2, 4, 1.71),
#  (7, 1020, 'HUILE TOURNESOL 25 L', 2, 2, 37.14),
#  (8, 1021, 'HUILE TOURNESOL 5 L', 2, 2, 8.0),
#  (9, 1022, 'HUILE TOURNESOL 1 L', 2, 4, 1.6),
#  (10, 1031, 'HUILE OLIVE 5 L', 2, 2, 24.0),
#  (11, 1032, 'HUILE OLIVE 1 L', 2, 4, 4.83),
#  (12, 1033, 'HUILE OLIVE VIERGE EXTRA BENOIT BV 1L', 2, 4, 6.8),
#  (13, 1034, 'HUILE OLIVE EXTRA VIERGE 250ML ITALIANO', 2, 14, 3.98),
#  (14, 1035, 'HUILE OLIVE SPRAY 25CL - CODEFA', 2, 15, 4.45),
#  (15, 1036, 'HUILE OLIVE VIERGE EXTRA JEAN ROMEO 75CL', 2, 4, 4.43),
#  (16, 1039, 'HUILE PIMENTEE 50CL - LESIEUR', 2, 4, 6.43),
#  (17, 1040, 'HUILE FRITURE CUISSON 25 L', 2, 2, 45.77),
#  (18, 1041, 'HUILE FRITURE CUISSON 5 L', 2, 2, 9.15),
#  (19, 1042, 'HUILE OLIVE 25 CL VERRE', 2, 4, 5.7),
#  (20, 1047, 'HUILE OLIVE BV 50CL', 2, 4, 4.45),
#  (21, 1054, 'HUILE OLIVE TRUFFE 250ML', 2, 4, 12.15),
#  (22, 1055, 'HUILE TRUFFE BLANCHE 250 ML EMPORIO', 2, 4, 12.0),
#  (23, 1070, 'HUILE PEPIN DE RAISIN 5L', 2, 2, 17.97),
#  (24, 1072, 'HUILE PEPIN DE RAISIN 1L', 2, 4, 3.91),
#  (25, 1080, 'BOMBE A GRAISSE 600 ML', 2, 15, 4.93),
#  (26, 1110, 'HUILE RISSO ELITE BIDON 10 L', 2, 2, 28.45),
#  (27, 1130, "HUILE D'OLIVE AU PIMENT 25CL VR-CODEFA", 2, 4, 2.99),
#  (28, 1230, 'HUILE PIMENTEE X 200', 2, 29, 7.89),
#  (29, 1232, 'HUILE PIMENTEE GYMA X 1000', 2, 29, 27.15),
#  (30, 1300, 'HUILE DE NOIX 25 CL', 2, 4, 5.37),
#  (31, 1305, 'HUILE DE NOISETTE 25 CL', 2, 4, 5.06),
#  (32, 1400, 'HUILE DE SESAME 600 ML', 2, 4, 10.92),
#  (33, 2015, 'CANTAL RAPE TRADILAIT 2KG', 34, 34, 6.94),
#  (34, 2020, 'CANTAL RAPE TRAD-SAC 2.5 KG', 34, 35, 19.55),
#  (35, 2025, 'CANTABRIK RAPE KAASBRIK - SAC 2KG', 34, 35, 11.29),
#  (36, 2030, 'CANTAMIL SAC 2 KG', 34, 35, 14.71),
#  (37, 2031, 'FROMAGE IL FILANTE SAC 2KG', 34, 35, 13.24),
#  (38, 2050, 'ASIAGO 1/4 DE MEULE-LE KG', 34, 34, 11.43),
#  (39, 2055, 'CANTAL JEUNE MEULE -  LE KG', 34, 34, 8.51),
#  (40, 2100, 'EMMENTAL BLOC ENV. 3 KG - LE KG', 34, 34, 6.75),
#  (41, 2101, 'EMMENTAL BLOC ENV 1.5 KG - LE KG', 34, 34, 7.62),
#  (42, 2105, 'EMMENTAL LS ENV 250G - LE KG', 34, 34, 9.39),
#  (43, 2110, 'CRU/SAVOIE 1/4 (MEULE TARENT) - LE KG -', 34, 34, 9.99),
#  (44, 2112, 'CROUTE FLEURIE KG', 34, 34, 12.79),
#  (45, 2125, 'EMMENTAL TRANCHE  5X15 - 1 KG', 34, 46, 8.15),
#  (46, 2130, 'EMMENTAL RAPE FIN 1KG', 34, 47, 6.45),
#  (47, 2131, 'EMMENTAL RAPE GROS MULIN 1KG', 34, 47, 5.78),
#  (48, 2132, 'FROMAGE RAPE(4 FROM.)  POUR FONDUE 1 KG', 34, 49, 10.31),
#  (49, 2150, 'GRANA BLOC - LE KG', 34, 34, 15.22),
#  (50, 2151, 'GRANA PADANO 28% POINTE 200G', 34, 46, 3.71),
#  (51, 2152, 'GRANA PADANO 1/8- LE KG', 34, 34, 15.33),
#  (52, 2153, 'PARMESAN BL REGGIANO (PCS+/- 1KG)- LE KG', 34, 34, 18.89),
#  (53, 2154, 'GRANA PADANO PETALE BARQ 500 G', 34, 49, 8.31),
#  (54, 2155, 'PARMESAN REGGIANO PETALE BARQ 500 G', 34, 49, 13.43),
#  (55, 2161, 'GRAN LEO SACHET 1KG', 34, 47, 9.74),
#  (56, 2163, 'PARMESAN REGGIANO RAPE 500G', 34, 47, 12.33),
#  (57, 2165, 'GRANA PADANO RAPE  BTE FER 1KG', 34, 58, 16.73),
#  (58, 2175, 'COMTE BLOC - LE KG', 34, 34, 14.29),
#  (59, 2180, 'BEAUFORT 1/8 - 45 % MG - LE KG', 34, 34, 19.43),
#  (60, 2190, 'ABONDANCE AOP TRADITION MEULE - LE KG', 34, 34, 13.79),
#  (61, 2200, 'ROQUEFORT PAIN 1/2 LUNE - LE KG', 34, 34, 13.17),
#  (62, 2205, 'ROQUEFORT DES 500G CROUZAT', 34, 49, 9.01),
#  (63, 2211, 'ROQUEFORT SOCIETE PORT 20 G X 8', 34, 46, 4.54),
#  (64, 2253, 'RACLETTE TRANCHEE PIECE 400G', 34, 46, 3.5),
#  (65, 2260, 'RACLETTE PASTEURISEE - KG', 34, 34, 7.07),
#  (66, 2261, 'RACLETTE LAIT CRU SAVOIE - KG', 34, 34, 11.21),
#  (67, 2262, 'RACLETTE LAIT CRU - KG', 34, 34, 8.21),
#  (68, 2300, 'MOZZARELLA 1KG - MAESTRELLA', 34, 46, 6.23),
#  (69, 2310, 'MOZZARELLA ITALIENNE 1 KG', 34, 46, 7.17),
#  (70, 2330, 'MOZZARELLA 10 X 125G', 34, 71, 0.84),
#  (71, 2331, 'MOZZARELLA DI BUFFALA  12X125 G', 34, 71, 1.86),
#  (72, 2332, 'MOZZA BURRATA 200 G X 6', 34, 71, 3.3),
#  (73, 2334, 'MOZZA BURRATINA 120G X10', 34, 71, 2.27),
#  (74, 2335, 'MOZZARELLA TR. RONDE 10 CM  1KG', 34, 49, 8.6),
#  (75, 2336, 'GOUDA TRANCHES 10X10 20G X50', 34, 49, 8.29),
#  (76, 2352, 'MOZZARELLA CERISE 8G POT 1KG', 34, 77, 9.99),
#  (77, 2353, 'MOZZARELLA CERISE 8G POT 500G', 34, 77, 4.99),
#  (78, 2381, 'MOZZARELLA COSS  MAES 2.5 KG', 34, 35, 12.55),
#  (79, 2382, 'MOZZARELLA COSSETTE KAASB - SAC 2KG', 34, 35, 9.76),
#  (80, 2384, 'MOZZARELLA MAESTRELLA RAPE 2.5 KG', 34, 35, 12.55),
#  (81, 2385, 'MOZZA/EMMENT.EMANIO-SAC 2.5 KG', 34, 35, 13.92),
#  (82, 2390, 'MOZZARELLA RAPEE CANTADORA - SAC 2.5KG', 34, 35, 12.77),
#  (83, 2400, 'CHEVRE BUCHE 2 X 1 KG', 34, 71, 9.99),
#  (84, 2410, 'CHEVRE BUCHETTE 180 G', 34, 46, 1.83),
#  (85, 2411, 'CHEVRE STE MAURE TOURAINE 220 G', 34, 46, 7.49),
#  (86, 2415, 'CHEVRE MELANGE GUSTINE 850GX2', 34, 71, 6.84),
#  (87, 2425, 'MI CHEVRE BUCHETTE 180G MELUSINE', 34, 46, 1.29),
#  (88, 2430, 'TOAST O CHEVRE  750G (CHEVRE A TARTINER)', 34, 49, 11.76),
#  (89, 2455, 'CROTTIN CHAVIGNOL AOP 60 G X 12', 34, 90, 23.86),
#  (90, 2469, 'CROTTIN TRAITEUR 60GX12 CAIS/ BOIS', 34, 90, 11.61),
#  (91, 2470, 'CROTTIN  AFFINE  60G X 15  BOIS', 34, 90, 13.64),
#  (92, 2471, 'CROTTIN BRASSERIE 80G X 12', 34, 90, 17.46),
#  (93, 2472, 'CROTTIN SPECIAL CUISSON 20 G X 24', 34, 90, 12.19),
#  (94, 2477, 'ST MARCELLIN AFF. 80G X 16 C/BOIS', 34, 90, 13.91),
#  (95, 2482, 'CHAPEL FOUR 45% 20 G X 12', 34, 49, 3.9),
#  (96, 2500, 'BRIE 60 % ENV. 3KG - LE KG', 34, 34, 6.59),
#  (97, 2510, 'BRIE DE MEAUX L.CRU 50% 1/2', 34, 34, 12.79),
#  (98, 2530, 'BRIE PIECE 1 KG', 34, 46, 7.5),
#  (99, 2540, 'LIVAROT AOP 40% 500G  - LA PIECE', 34, 46, 9.08),
#  (100, 2545, 'MUNSTER FERMIER 50% - LE KG', 34, 34, 13.82),
#  (101, 2550, 'CORSICA 48% - 500G', 34, 34, 22.71),
#  (102, 2560, 'PONT L EVEQUE 400 G', 34, 46, 6.44),
#  (103, 2570, 'CAMEMBERT NORMAND 20 % BTE BOIS', 34, 58, 2.28),
#  (104, 2571, 'CAMEMBERT AOP LAIT CRU 240G', 34, 58, 2.99),
#  (105, 2572, 'CAMEMBERT ENT. PRESIDENT 250G', 34, 58, 2.66),
#  (106, 2573, 'CAMEMBERT COEUR DE LION 250 G', 34, 58, 2.58),
#  (107, 2575, 'CAMEMBERT ENTIER 240 G', 34, 58, 1.33),
#  (108, 2581, 'CAMEMBERT 30 G X 8 PORT. PRESIDENT', 34, 58, 2.29),
#  (109, 2600, 'EDAM PAIN - LE KG', 34, 34, 6.41),
#  (110, 2631, 'GOUDA PORTIONS 30GX100 DOMALAIT', 34, 58, 36.71),
#  (111, 2640, 'CHEDDAR ROUGE BLOC - LE KG', 34, 34, 9.89),
#  (112, 2641, 'CHEDDAR RAPE SAC 1KG', 34, 35, 8.85),
#  (113, 2650, 'CHEDDAR TOASTINETTE X 84 TRANCHES', 34, 114, 6.2),
#  (114, 2700, 'BUCHE BLEUE - LE KG', 34, 34, 7.79),
#  (115, 2701, "FOURME D'AMBERT CUBES 500G", 34, 46, 7.75),
#  (116, 2705, 'TENDRE BLEU 400 G', 34, 46, 5.84),
#  (117, 2710, "BLEU D'AUVERGNE AOP 1/2 50% - LE KG", 34, 34, 8.5),
#  (118, 2715, "FOURME D'AMBERT  - LE KG", 34, 34, 8.85),
#  (119, 2720, 'GORGONZOLA 1/8 - LE KG', 34, 34, 9.91),
#  (120, 2725, 'TOMMETTE DE BREBIS 800 G - LE KG', 34, 34, 14.4),
#  (121, 2726, 'FROMAGE DE PAYS VACHE  PIECE 400 G', 34, 46, 3.68),
#  (122, 2727, 'FROMAGE DE PAYS CHEVRE PIECE 400 G', 34, 46, 6.03),
#  (123, 2731, 'TOMME GRISE - LE KG', 34, 34, 8.46),
#  (124, 2739, 'TOMME DE BREBIS - LE KG', 34, 71, 14.29),
#  (125, 2740, 'TOMME DE CHEVRE - LE KG', 34, 34, 14.46),
#  (126, 2741, 'TOMME VACHE TRUFFES NOIRES BLANCHES KG', 34, 34, 56.64),
#  (127, 2750, 'SBRINTZ 1/8 - LE KG', 34, 34, 25.9),
#  (128, 2760, 'SAINT NECTAIRE - LE KG', 34, 34, 10.22),
#  (129, 2762, 'MORBIER - LE KG', 34, 34, 12.23),
#  (130, 2765, "MONT D'OR 500G - LA PIECE", 34, 46, 7.25),
#  (131, 2766, 'BOIS BLOND 55% 230G', 34, 46, 2.74),
#  (132, 2775, 'REBLOCHON - LA PIECE', 34, 46, 5.94),
#  (133, 2777, 'BRILLAT SAVARIN 500G', 34, 46, 6.28),
#  (134, 2800, 'RICOTTA 1.5 KG', 34, 46, 6.5),
#  (135, 2810, 'FETA CUBE 900G', 34, 58, 12.24),
#  (136, 2812, 'BROUSSE DE BREBIS PERAC 500G', 34, 49, 5.24),
#  (137, 2815, 'FETA BLOC - LE KG', 34, 34, 12.12),
#  (138, 2832, 'PHILADELPHIA NATURE - 1.65KG', 34, 58, 18.02),
#  (139, 2833, 'SAINT MORET NATURE - 1KG', 34, 58, 14.21),
#  (140, 2834, 'BOURSIN CUISINE AIL/FH 1KG', 34, 58, 15.61),
#  (141, 2835, 'SAINT MORET NATURE 25 G X 24', 34, 49, 7.42),
#  (142, 2850, 'MINI BABYBEL 22 G X 96', 34, 58, 42.81),
#  (143, 2854, 'KIRI 65 %  20 G X 80', 34, 58, 24.24),
#  (144, 2855, 'VACHE QUI RIT 17.5 G X 80', 34, 58, 16.49),
#  (145, 2859, 'VACHE QUI RIT BAC 1 KG', 34, 146, 11.69),
#  (146, 2900, 'FROMAGE BLANC 40% SEAU 5 KG', 34, 147, 11.24),
#  (147, 2910, 'FROMAGE BLANC 20% POT 1 KG', 34, 77, 2.46),
#  (148, 2920, 'YAOURT POT VERRE PECHE 135GX2 DAN', 34, 149, 1.57),
#  (149, 2921, 'YAOURT POT VERRE FRAISE 135GX2 DAN', 34, 149, 1.59),
#  (150, 2922, 'YAOURT POT VERRE CITRON 125G X 4 LAITIER', 34, 114, 2.39),
#  (151, 2923, 'YAOURT POT VERRE VANILL 125G X 4 LAITIER', 34, 114, 2.44),
#  (152, 2930, 'ACTIVIA NATURE 125GX4  DANONE', 34, 114, 2.63),
#  (153, 2932, 'YAOURT NATURE 125 G X 16 DANONE', 34, 114, 4.23),
#  (154, 2935, 'SOJA SUN X 4', 34, 114, 2.15),
#  (155, 2939, 'YAOURT A LA GRECQUE 4X150GR', 34, 114, 2.7),
#  (156, 2940, 'YAOURT PANIER DE YOPLAIT 130G X 16', 34, 114, 6.16),
#  (157, 2945, 'DANETTE 4 X 125G', 34, 114, 2.29),
#  (158, 2946, 'FLANBY 100G X 4 NESTLE', 34, 114, 1.74),
#  (159, 29123, 'YAOURT POT VERRE NATURE 135GX2 DAN', 34, 149, 1.31),
#  (160, 999918, 'TOMME BREBIS CORSE OTTAVI KG', 34, 34, 27.09),
#  (161, 3010, 'CREME SUCREE VANILLEE 2L DEBIC', 162, 4, 10.55),
#  (162, 3020, 'CREME UHT 30%  GERENTES - 1L', 162, 163, 3.02),
#  (163, 3021, 'CREME UHT 30% BAIGNES - 1L', 162, 163, 3.65),
#  (164, 3030, 'CREME UHT 35% VAL DE SAIRE  1L', 162, 163, 3.65),
#  (165, 3040, 'CREME EXCELLENCE ELLE & VIRE -1L', 162, 163, 5.32),
#  (166, 3051, 'CREME LIAISON FOISON 1L BLUE BAND 31 %', 162, 4, 4.66),
#  (167, 3052, 'CREME VEGETOP 1L DEBIC', 162, 4, 3.21),
#  (168, 3053, 'CREME VEGETOP SUCREE 1L DEBIC', 162, 163, 4.13),
#  (169, 3055, 'CREME SPEC. CUISSON CUISINEL -1L', 162, 163, 3.17),
#  (170, 3066, 'CREME UHT 35% GRAND FERMAGE 1L', 162, 163, 3.98),
#  (171, 3067, 'CREME UHT CUISSON 18% GRAND/F BLEUE - 1L', 162, 163, 2.85),
#  (172, 3068, 'CREME UHT TENUE ET FOISON 35 % 1L DEBIC', 162, 163, 5.35),
#  (173, 3070, 'CREME BRULEE  ELLE&VIRE 1L', 162, 163, 6.12),
#  (174, 3071, 'CREME BRULEE 1L DEBIC', 162, 4, 5.89),
#  (175, 3075, 'CREME BRULEE MONTAIGU - 1L', 162, 163, 5.85),
#  (176, 3080, 'TIRAMISU ELLE & VIRE - 1L', 162, 163, 7.2),
#  (177, 3081, 'TIRAMISU PREPARATION 1L DEBIC', 162, 4, 7.23),
#  (178, 3087, 'CREAM CHEESE POT 1KG  E&V', 162, 58, 11.62),
#  (179, 3088, 'PREP. CHEESECAKE UHT PRESIDENT-1L', 162, 58, 6.98),
#  (180, 3090, 'FAISSELLE 100 G X 4', 162, 114, 1.91),
#  (181, 3100, 'CREME ANGLAISE 2L DEBIC', 162, 4, 6.26),
#  (182, 3115, 'CREME ANGLAISE MONTAIGU - 1L', 162, 163, 2.55),
#  (183, 3200, 'CREME FRAICHE EPAISSE 30 % SEAU 5 L', 162, 147, 17.75),
#  (184, 3210, 'CREME FRAICHE EPAISSE 30%  MG  1KG', 162, 147, 4.26),
#  (185, 3400, 'CHANTIBIC BOMBE 700 ML DEBIC', 162, 4, 7.17),
#  (186, 3450, 'PANNA COTTA 1 L DEBIC', 162, 4, 5.7),
#  (187, 3451, 'PANNA COTTA ELLE & VIRE-1L', 162, 163, 7.2),
#  (188, 3452, 'CREME CARAMEL 1L DEBIC', 162, 4, 5.16),
#  (189, 3500, 'GRATIN FRUIT SABAYON ELLE & VIRE-1L', 162, 163, 8.28),
#  (190, 3505, 'MOUSSE CHOC. NOIR YOPLAIT- 5L', 162, 147, 18.69),
#  (191, 3508, 'MOUSSE CHOCOLAT YOPLAIT-2,5L', 162, 147, 10.05),
#  (192, 3510, 'MASCARPONE 500 G', 162, 58, 3.93),
#  (193, 4010, 'LAIT 1/2 ECR BRICK  1LX6', 194, 71, 0.75),
#  (194, 4020, 'LAIT 1/2 ECR BOUT. BRIDEL 1LX6', 194, 71, 1.3),
#  (195, 4050, 'LAIT ENTIER BRIDEL 1LX6', 194, 71, 1.49),
#  (196, 4060, 'LAIT ENTIER BRICK 1LX6', 194, 71, 0.93),
#  (197, 4200, 'LAIT POUDRE 1/2 EC.NESTLE  5 KG', 194, 47, 54.3),
#  (198, 4300, 'LAIT CONCENTRE NS 410 G', 194, 58, 1.89),
#  (199, 4350, 'LAIT CONCENTRE SUCRE 397G NESTLE', 194, 58, 3.02),
#  (200, 4400, 'LAIT GLORIA NS DOSES 7.5 G X 300', 194, 29, 25.41),
#  (201, 2742, 'SPECIALITÉ BASE BEURRE A LA TRUFFE 165G', 202, 46, 16.0),
#  (202, 2743, 'BEURRE A LA TRUFFE 500G', 202, 46, 43.16),
#  (203, 5010, 'BEURRE PLAQUETTE  250 G - LE KG', 202, 34, 8.6),
#  (204, 5015, 'BEURRE 125 G PRESIDENT-LE KG', 202, 34, 11.07),
#  (205, 5016, 'BEURRE 250G PRESIDENT- LE  KG', 202, 34, 10.09),
#  (206, 5017, 'BEURRE DOUX AOP 2KG (CARTON 10KG)', 202, 29, 96.9),
#  (207, 5020, 'BEURRE ROULEAU 1KG', 202, 46, 8.31),
#  (208, 5030, 'BEURRE MICROPAINS 10 G X 100', 202, 46, 9.53),
#  (209, 5031, 'BEURRE MICROPAINS 1/2 SEL 10 G X 100', 202, 46, 8.92),
#  (210, 5032, 'BEURRE COUPELLE AOP 25G X 48 ISIGNY', 202, 46, 16.93),
#  (211, 5050, 'BEURRE CONVIETTE 15G X 30', 202, 46, 8.57),
#  (212, 5051, 'BEURRE ECHIRE 30 G X 20 X 5 - CARTON', 202, 29, 66.62),
#  (213, 5100, 'BEURRE 1/2 SEL PLAQ 250 G - LE KG', 202, 34, 9.1),
#  (214, 5200, 'MARGARINE CUISINE 500G - BARQUETTE', 202, 49, 1.35),
#  (215, 5205, 'SAINDOUX 250 G', 202, 46, 1.93),
#  (216, 5300, 'TARTIMALIN DOUX BARQUETTE 1 KG', 202, 46, 7.85),
#  (217, 6010, 'CHORIZO CULAR COUSU FORT - LE  KG', 218, 34, 7.01),
#  (218, 6011, 'CHORIZO FORT PIECE 200 G', 218, 46, 1.99),
#  (219, 6012, 'CHORIZO DOUX PIECE 200G', 218, 46, 2.4),
#  (220, 6013, 'CHORIZO PIZZA PETITE TRANCHE 500G', 218, 49, 5.49),
#  (221, 6014, 'CHORIZO EXTRA VELA GD TR  500G', 218, 49, 4.85),
#  (222, 6015, 'FIGATELLI CORSE - LE KG', 218, 34, 9.15),
#  (223, 6016, 'FIGATELLI CORSE PIECE (KG)', 218, 34, 18.57),
#  (224, 6021, 'MORTADELLE 60T - 2 X 250G', 218, 46, 8.59),
#  (225, 6022, 'MORTADELLE SANGLIER TRUFFE KG', 218, 34, 23.9),
#  (226, 6040, 'ROSETTE PP - LE KG', 218, 34, 8.49),
#  (227, 6041, 'ROSETTE 10GX50 TR -  PAQUET 500 G', 218, 49, 5.34),
#  (228, 6049, 'COPPA STAGIONATA KG', 218, 34, 16.88),
#  (229, 6050, 'COPPA 1/2 - LE  KG', 218, 34, 12.3),
#  (230, 6051, 'PANCETTA -  LE KG', 218, 34, 11.56),
#  (231, 6052, 'COPPA TRANCHE 500 G', 218, 46, 8.9),
#  (232, 6053, 'PANCETTA TRANCHEE 500 G', 218, 46, 9.64),
#  (233, 6055, 'BRESAOLA 1/2  - LE  KG', 218, 34, 32.74),
#  (234, 6090, 'MERGUEZ PRECUITES  1 KG', 218, 47, 9.99),
#  (235, 6100, 'EPAULE CUITE DD STANDARD PIECE 5KG', 218, 46, 24.8),
#  (236, 6225, 'JAMBON CUIT SUP DD NAVARRE  LE KG', 218, 34, 5.86),
#  (237, 6230, 'JAMBON DD SUP 10TRX50G - LE PAQUET', 218, 114, 4.27),
#  (238, 6231, 'JAMBON SUP DD TORCHON 16TR 640 G', 218, 49, 6.33),
#  (239, 6232, 'BLANC DE DINDE 40G X18TR', 218, 49, 7.94),
#  (240, 6233, 'JAMBON DD SUP TORCH 20TRX40G', 218, 49, 8.0),
#  (241, 6234, 'JAMBON DE DINDE RECT HALAL 3.63 KG', 218, 46, 28.18),
#  (242, 6240, 'FAUSSE COUPE JAMBON PAQ 3KG', 218, 114, 13.39),
#  (243, 6241, 'CHUTE DE JAMBON - PAQUET 1 KG', 218, 114, 4.94),
#  (244, 6242, 'FAUSSE COUPE JAMBON PQT 2KG', 218, 114, 9.37),
#  (245, 6243, 'FAUSSE COUPE JAMBON AU KILO', 218, 34, 4.72),
#  (246, 6290, 'RIBS PORC PREC MEXIC  600G - LE KG', 218, 34, 10.82),
#  (247, 6300, 'LARDONS FUMES ALLUMETTES - 1 KG', 218, 49, 6.17),
#  (248, 6301, 'LARDONS FUMES GROS - 1 KG', 218, 49, 6.01),
#  (249, 6305, 'LARDONS SALES 1 KG', 218, 49, 6.56),
#  (250, 6310, 'BACON 42 TR  -  PAQUET 500 G', 218, 114, 5.86),
#  (251, 6315, 'BACON FUME - LE KG', 218, 34, 8.56),
#  (252, 6350, 'POITRINE FUMEE N°1 - LE KG', 218, 34, 6.25),
#  (253, 6352, 'POITRINE FUMEE TRANCHEE 500G', 218, 46, 4.62),
#  (254, 6360, 'POITRINE SALEE N°1 - LE KG', 218, 34, 7.44),
#  (255, 6400, 'JAMBON CRU ITALIEN 6 KG - LE KG', 218, 34, 8.73),
#  (256, 6401, 'JAMBON CRU SERRANO DEMI - LE KG', 218, 34, 12.39),
#  (257, 6403, 'JAMBON CRU DI NORCIA IGP AVEC OS - KG', 218, 34, 23.9),
#  (258, 6404, 'REGINA DI NORCIA CUISSE PORC MARINÉES KG', 218, 34, 28.9),
#  (259, 6405, 'UMBRIACO CUISSE PORC MARINÉE VIN KG', 218, 34, 28.9),
#  (260, 6406, 'GUANCIALE DI SUINO JOUE DE PORC KG', 218, 34, 25.9),
#  (261, 6407, 'GRANTARTUFO JAMBON BLANC TRUFFE KG', 218, 34, 39.9),
#  (262, 6420, 'SPECK 1/2 - LE KG', 218, 34, 14.9),
#  (263, 6425, 'JAMBON CRU PAYS 25G X 20 - BARQUETTE', 218, 49, 7.13),
#  (264, 6446, 'JAMBON DE PARME 20TX16 G -  PAQUET 320 G', 218, 49, 11.0),
#  (265, 6450, 'JAMBON DE PARME S/OS  8 KG - LE KG', 218, 34, 18.89),
#  (266, 6455, 'JAMBON SERRANO GAMBOA 30 TR - 500 G', 218, 49, 7.99),
#  (267, 6456, 'JAMBON SERRANO TR - 500 G ARROYO', 218, 49, 6.3),
#  (268, 6480, 'VIANDE DES GRISONS-  LE KG -', 218, 34, 40.84),
#  (269, 6500, 'PATE DE CAMPAGNE PAIN 2 KG', 218, 46, 8.4),
#  (270, 6520, 'PATE EN CROUTE RICHELIEU KG', 218, 34, 7.95),
#  (271, 6600, 'SAUCISSE DE STRASBOURG - 1 KG', 218, 47, 5.49),
#  (272, 6601, 'SAUCISSES DE FRANCFORT 1 KG', 218, 47, 5.56),
#  (273, 6603, 'SAUCISSES HOT DOG 1.4KG', 218, 47, 8.0),
#  (274, 6604, 'SAUCISSES FUMEE 120G X15 LE KG', 218, 34, 5.7),
#  (275, 6606, 'SAUCISSON DE PORC TRUFFE PARMESAN KG', 218, 34, 37.9),
#  (276, 6607, 'SAUCISSON AU FENOUIL KG', 218, 34, 24.9),
#  (277, 6608, 'SAUCISSE DE SANGLIER TRUFFE S/V KG', 218, 34, 49.9),
#  (278, 6609, 'SPIANATA DOUCE KG', 218, 34, 14.9),
#  (279, 6610, 'SAUCISSE SECHE COURBE 300G', 218, 47, 3.49),
#  (280, 6700, 'BL. FOIE GRAS CAN. MX 400 G', 218, 58, 16.47),
#  (281, 6781, 'GRAISSE D OIE 4/4', 218, 58, 5.56),
#  (282, 6782, 'GRAISSE CANARD 5/1', 218, 58, 15.75),
#  (283, 6783, 'GRAISSE CANARD 4/4', 218, 58, 5.18),
#  (284, 6810, 'MAGRET CANARD FUME TR 250G', 218, 114, 10.27),
#  (285, 6830, 'MAGRET DE CANARD CRU - LE  KG', 218, 34, 17.5),
#  (286, 6851, 'GESIERS DE CANARD EMINCES 4/4', 218, 58, 8.69),
#  (287, 6871, 'GESIERS DE DINDE EMINCES 4/4', 218, 58, 5.86),
#  (288, 6890, 'CONFIT DE CANARD 12 CUISSES 5/1', 218, 58, 34.99),
#  (289, 7100, 'OEUFS 53/63  CANADIENNE X 360', 290, 29, 55.57),
#  (290, 7105, 'OEUFS 63/73  CARTON X 180', 290, 29, 29.67),
#  (291, 7110, 'OEUFS 53/63  CARTON X 60', 290, 29, 10.17),
#  (292, 7115, 'OEUFS 53/63  CARTON X 90', 290, 29, 14.4),
#  (293, 7200, 'OEUFS ECALES X 40', 290, 47, 10.39),
#  (294, 7210, 'OEUFS ECALES SEAU X 150', 290, 147, 31.38),
#  (295, 7220, 'OEUF ECALE X 75', 290, 147, 26.14),
#  (296, 7300, 'OEUF ENTIER BIDON 2 L', 290, 2, 7.89),
#  (297, 7310, "BLANC D'OEUF BIDON  1 L", 290, 2, 4.17),
#  (298, 7311, 'OEUFS ENTIERS LIQUIDES 1 KG', 290, 2, 3.96),
#  (299, 7320, "JAUNE D'OEUF BIDON 1 L", 290, 2, 6.19),
#  (300, 7380, 'OEUFS POCHES X48', 290, 47, 25.08),
#  (301, 7500, 'OEUF NEIGE BARQUETTE 2.2 L', 290, 49, 2.54),
#  (302, 8809, 'SAUCE ANGLAISE - WORCESTERSHIRE - 300 ML', 303, 14, 2.45),
#  (303, 8101, 'KETCHUP BIDON COLONA  5 L', 303, 2, 8.22),
#  (304, 8102, 'KETCHUP HEINZ BID 5.7 KG', 303, 2, 20.12),
#  (305, 8103, 'SAUCE CAESAR 3 L COLONA', 303, 2, 12.2),
#  (306, 8106, 'KETCHUP PINGOUIN 5.5 KG LESIEUR', 303, 307, 21.02),
#  (307, 8110, 'KETCHUPIER SOUPLE AMORA 485 G', 303, 14, 2.52),
#  (308, 8111, 'SAUCE KETCHUP CALIFORNIA 970 ML', 303, 309, 5.37),
#  (309, 8113, 'KETCHUP FLACON SOUPLE 342 G HEINZ', 303, 14, 2.15),
#  (310, 8120, 'KETCHUP HEINZ VERRE - 342 G', 303, 4, 2.3),
#  (311, 8125, 'KETCHUP SOUPLE HEINZ 910G', 303, 309, 5.94),
#  (312, 8129, 'KETCHUP DOSES X 600', 303, 29, 25.0),
#  (313, 8130, 'KETCHUP DOSES 10 G X 500 - COLONA', 303, 29, 19.48),
#  (314, 8132, 'KETCHUP DOSE 10ML X 200 HEINZ', 303, 29, 13.85),
#  (315, 8135, 'KETCHUP POT VERRE HEINZ 33 ML X 80', 303, 29, 47.46),
#  (316, 8140, 'KETCHUP 950 ML COLONA', 303, 309, 3.05),
#  (317, 8150, 'KETCHUP VOLPACK HEINZ-15KG', 303, 29, 33.24),
#  (318, 8201, 'MAYONNAISE COLONA - SEAU 5 KG', 303, 147, 8.95),
#  (319, 8203, 'MAYONNAISE HTE FERMETE LESIEUR SEAU 5KG', 303, 147, 14.29),
#  (320, 8206, 'MAYONNAISE PINGOUIN 5 KG LESIEUR', 303, 307, 21.41),
#  (321, 8210, 'MAYONNAISIER AMORA 395G', 303, 309, 4.17),
#  (322, 8230, 'MAYONNAISE DOSES 10 ML X 500 - COLONA', 303, 29, 24.24),
#  (323, 8235, 'MAYONNAISE POT VERRE HEINZ 33 ML X 80', 303, 29, 47.49),
#  (324, 8240, 'MAYONNAISE SQUEEZ  950ML COLONA', 303, 309, 3.5),
#  (325, 8241, "SAUCE FRED'S 950ML - CLASSIC FOODS", 303, 4, 6.0),
#  (326, 8245, 'SAUCE MAYONNAISE CALIFORNIA 970 ML', 303, 309, 6.26),
#  (327, 8252, 'MAYONNAISE DOSE HEINZ 12G X 200', 303, 29, 25.05),
#  (328, 8300, 'MOUTARDE SEAU 5 KG', 303, 147, 7.55),
#  (329, 8301, 'MOUTARDE POT 1 KG', 303, 77, 2.13),
#  (330, 8302, 'MOUTARDE AU MIEL 340G', 303, 309, 4.33),
#  (331, 8304, 'MOUTARDE PINGOUIN 5.3 KG LESIEUR', 303, 307, 14.77),
#  (332, 8305, "MOUTARDE A L'ANCIENNE SEAU 5 KG", 303, 147, 7.55),
#  (333, 8306, 'MOUTARDE AMORA-SEAU 5 KG', 303, 147, 13.87),
#  (334, 8307, "MOUTARDE A L' ANCIENNE POT 1KG", 303, 77, 2.3),
#  (335, 8310, 'MOUTARDIER SOUPLE AMORA 265 G', 303, 309, 2.38),
#  (336, 8311, 'MAYONNAISE SOUPLE AMORA 235 G', 303, 14, 2.99),
#  (337, 8320, 'MOUTARDE SQUEEZ 950 ML COLONA', 303, 309, 3.97),
#  (338, 8325, 'SAUCE MOUTARDE CALIFORNIA 970 ML', 303, 309, 5.37),
#  (339, 8330, 'MOUTARDE DOSES 4G X 1000 COLONA', 303, 29, 19.77),
#  (340, 8332, 'MOUTARDE DOSE HEINZ 7G X 250', 303, 29, 13.39),
#  (341, 8333, "MOUTARDE FRENCH'S 226 G", 303, 309, 2.36),
#  (342, 8335, 'MOUTARDE POT VERRE HEINZ 33 ML X 80', 303, 29, 47.46),
#  (343, 8340, 'SAVORA AMORA 385 G', 303, 77, 2.47),
#  (344, 8345, 'WASABI TUBE 43 G', 303, 345, 3.0),
#  (345, 8360, 'HARISSA CAP BON 4/4', 303, 58, 2.38),
#  (346, 8370, 'HARISSA CAP BON 1/2', 303, 58, 1.31),
#  (347, 8380, 'HARISSA TUBE 70 G', 303, 345, 0.55),
#  (348, 8400, 'SAUCE SALADE- BIDON 5 L', 303, 2, 4.85),
#  (349, 8405, 'SAUCE SALADE COLONA - 950 ML', 303, 309, 2.52),
#  (350, 8406, 'SAUCE SALADE CAESAR 1L AMORA', 303, 309, 6.82),
#  (351, 8408, 'SAUCE SALADE RANCH 3L - CLASSIC FOOD', 303, 2, 19.4),
#  (352, 8430, 'SAUCE SALADE DOSETTE X 500 COLONA', 303, 29, 10.25),
#  (353, 8431, 'CALIFORNIAN SWEET ONION RELISH 320GR', 303, 309, 3.38),
#  (354, 8440, 'SAUCE SALADE DOSETTE HEINZ X 200', 303, 29, 26.17),
#  (355, 8500, 'SEL FIN CEREBOS - SEAU 5KG', 303, 147, 5.3),
#  (356, 8502, 'SEL FIN - SAC 10 KG', 303, 35, 4.28),
#  (357, 8503, 'SEL FIN  SACHET 1 KG', 303, 47, 0.44),
#  (358, 8505, 'SEL FIN IODE BTE VERS. 500 G CEREBO', 303, 58, 0.75),
#  (359, 8506, 'SEL FIN - BTE VERS. 750G', 303, 58, 0.72),
#  (360, 8510, 'SEL GROS CEREBOS - SEAU 5KG', 303, 147, 5.92),
#  (361, 8512, 'SEL GROS SAC 10 KG', 303, 35, 4.44),
#  (362, 8513, 'SEL GROS BALEINE 1 KG', 303, 35, 1.2),
#  (363, 8514, 'SEL GROS SACHET 1 KG', 303, 35, 0.49),
#  (364, 8515, 'SEL GROS DE GUERANDE 5 KG', 303, 35, 9.9),
#  (365, 8516, 'SEL GROS DE GUERANDE SACHET 1 KG', 303, 35, 1.93),
#  (366, 8521, 'FLEUR DE SEL CAMARGUE - POT 125 G', 303, 77, 5.32),
#  (367, 8525, 'FLEUR DE SEL DE GUERANDE POT 1 KG', 303, 77, 18.65),
#  (368, 8530, 'SEL DOSES X 2000', 303, 29, 3.89),
#  (369, 8550, 'SALIERE 50GX20 - LE LOT', 303, 370, 8.95),
#  (370, 8560, 'SEL MOULIN 60GX6 - DUCROS', 303, 370, 11.85),
#  (371, 8590, 'SEL AU CELERI - FLACON 90 G', 303, 14, 1.6),
#  (372, 8600, 'CORNICHONS BOITE 5/1 CAL. 150 +', 303, 58, 6.99),
#  (373, 8601, 'CORNICHONS MALOSSOL BOCAL 770G', 303, 374, 3.59),
#  (374, 8603, 'CORNICHONS 60/79 BOCAL 72CL', 303, 374, 2.01),
#  (375, 8605, 'CORNICHONS 4/4', 303, 58, 1.96),
#  (376, 8606, 'CORNICHONS BOCAL 60/79 37 CL', 303, 374, 1.88),
#  (377, 8607, 'CORNICHONS RUSSE 106CL', 303, 374, 3.79),
#  (378, 8608, 'CORNICHONS SLICED  3.76KG CLAS.FOOD', 303, 374, 13.61),
#  (379, 8610, 'CORNICHONS BOITE 5/1 CAL. 80/119', 303, 58, 8.99),
#  (380, 8615, 'CORNICHONS RONDELLES  5/1', 303, 58, 6.46),
#  (381, 8620, 'CORNICHONS 120/130 BCL 950 G MAILLE', 303, 374, 13.7),
#  (382, 8651, 'CAPRES BOCAL 2/1- 1700ML', 303, 374, 5.7),
#  (383, 8652, 'CAPRES FINES 4/4', 303, 58, 2.66),
#  (384, 8653, 'CAPRES SURFINES 105 ML VITALYS', 303, 374, 1.34),
#  (385, 8654, 'CAPRES CAPUCINES 4/4', 303, 58, 3.97),
#  (386, 8655, 'CAPRONS BOCAL 680 G', 303, 374, 4.8),
#  (387, 8660, 'CAPRES CAPUCINES 5/1', 303, 58, 18.79),
#  (388, 8690, 'OIGNONS BLANCS 5/1', 303, 58, 6.96),
#  (389, 8691, 'OIGNONS BLANCS BOCAL 265 CL - KUHNE', 303, 374, 11.81),
#  (390, 8692, 'OIGNONS BLANCS BOCAL 72 CL', 303, 374, 1.6),
#  (391, 8701, 'VINAIGRE DE VIN 6° PET 1,5L', 303, 4, 1.24),
#  (392, 8702, 'VINAIGRE DE VIN 1L', 303, 4, 1.21),
#  (393, 8711, "VINAIGRE D' ALCOOL BLANC  1,5L", 303, 4, 0.78),
#  (394, 8720, 'VINAIGRE BALSAMIQUE GIACOBAZZI-BTLE 1L', 303, 4, 4.67),
#  (395, 8722, 'VINAIGRE BALSAMIQUE - 50 CL GIACOBAZZI', 303, 14, 2.68),
#  (396, 8724, 'CREME BALSAM. BLANCHE GIACOBAZZI- 235ML', 303, 14, 3.37),
#  (397, 8725, 'VINAIGRE BALSAMIQUE GIACOBAZZI-BID 5 L', 303, 2, 15.55),
#  (398, 8726, 'CREME BALSAMIQUE GIACOBAZZI - 235ML', 303, 14, 3.37),
#  (399, 8727, 'VINAIGRE BALSAMIQUE SPRAY 25CL - CODEFA', 303, 15, 4.53),
#  (400, 8728, 'VINAIGRE TOMATE MUTTI-BTLE 500ML', 303, 4, 2.73),
#  (401, 8729, 'CREME BALSAMIQUE  GIACOBAZZI - 500ML', 303, 14, 5.52),
#  (402, 8730, 'VINAIGRE DE XERES-BTLE 1L', 303, 4, 2.73),
#  (403, 8731, 'VINAIGRE DE XERES-BTLE 50 CL', 303, 4, 2.02),
#  (404, 8732, 'VINAIGRE BALSAMIQUE 4F GIACOBAZZI-250ML', 303, 4, 2.96),
#  (405, 8733, 'CREME BALSAM. FRAMBOISE 400ML', 303, 14, 8.21),
#  (406, 8734, 'VINAIGRETTE SPRAY 25CL - CODEFA', 303, 15, 3.36),
#  (407, 8740, 'VINAIGRE DE FRAMBOISE - BTLE 1L', 303, 4, 2.4),
#  (408, 8750, 'VINAIGRE BLANC AIGRE DOUX 500 ML GIACOBA', 303, 4, 2.98),
#  (409, 8751, 'VINAIGRE DE CIDRE - BTLE 50CL', 303, 4, 1.36),
#  (410, 8760, 'VINAIGRE DE RIZ 900ML', 303, 4, 10.99),
#  (411, 8761, 'VINAIGRE DE VIN VIEUX - BTLE 50CL', 303, 4, 2.69),
#  (412, 8770, 'JUS DE CITRON YUZU - BTLE 360 ML', 303, 4, 25.53),
#  (413, 8789, 'JUS DE CITRON VICTORIA- BTLE 1L', 303, 4, 1.96),
#  (414, 8790, 'PULCO CITRON 70 CL', 303, 4, 4.34),
#  (415, 8791, 'PULCO CITRON VERT 70 CL', 303, 4, 4.33),
#  (416, 8795, 'PULCO ORANGE 70  CL', 303, 4, 3.65),
#  (417, 8800, 'SAUCE ANGLAISE(WORCESTERSHIRE)  PM 150ML', 303, 14, 2.2),
#  (418, 8801, 'SAUCE ANGLAISE (WORCESTERSHIRE) GM 600ML', 303, 14, 5.35),
#  (419, 8809, 'SAUCE SOJA KIKOMAN SUCREE 975ML', 303, 4, 9.51),
#  (420, 8810, 'SAUCE SOJA HEINZ 150ML', 303, 14, 2.1),
#  (421, 8811, 'SAUCE SOJA KIKOMAN - 1 L', 303, 4, 8.52),
#  (422, 8812, 'SAUCE SOJA / CHAMPIGNON NOIR 500ML', 303, 4, 2.26),
#  (423, 8813, 'SAUCE HUITRE 907G', 303, 4, 6.75),
#  (424, 8814, 'SAUCE SOJA LESS KIKOMAN 1L', 303, 4, 9.69),
#  (425, 8815, 'GINGEMBRE VINAIGRE ROSE 1KG', 303, 47, 9.44),
#  (426, 8816, 'SAUCE SOJA SUCRÉE 250ML', 303, 14, 2.74),
#  (427, 8817, 'SAUCE BROOKLYN 950ML - CLASSIC FOODS', 303, 4, 6.38),
#  (428, 8818, 'SAUCE CAESAR SALADE 3L - CLASSIC FOOD', 303, 2, 18.9),
#  (429, 8820, 'SAUCE DE POISSON (N. MAN) 725 ML', 303, 4, 2.75),
#  (430, 8821, 'SAUCE WOK SESAME SOJA - 1 L GOTAN', 303, 4, 17.9),
#  (431, 8833, 'SAUCE BIGY BURGER  950 ML NAWHALS', 303, 309, 5.2),
#  (432, 8837, 'SAUCE BIGBURGER COLONA 850 G SQUEEZE', 303, 309, 4.26),
#  (433, 8839, 'BARBECUE DOSE HEINZ 9 G X 250', 303, 29, 17.23),
#  (434, 8840, 'SAUCE BARBECUE 950 ML COLONA', 303, 309, 3.1),
#  (435, 8841, 'SAUCE BOURGYBURGER 950 ML COLONA', 303, 309, 3.93),
#  (436, 8842, 'SAUCE POIVRE - CHEF 1L', 303, 163, 7.76),
#  (437, 8843, 'SAUCE POIVRE RAVIGORE COLONA 850G', 303, 309, 3.97),
#  (438, 8844, 'SAUCE HAMBURGER 950 ML COLONA', 303, 309, 3.78),
#  (439, 8845, 'SAUCE HAMBURGER CALIFORNIA 970 ML', 303, 309, 6.1),
#  (440, 8846, 'SAUCE SAMOURAI 950 ML COLONA', 303, 309, 3.97),
#  (441, 8848, 'SAUCE TARTARE SQUEEZ 950 ML COLONA', 303, 309, 3.72),
#  (442, 8849, 'SAUCE SAMOURAI CALIFORNIA 970 ML', 303, 309, 6.4),
#  (443, 8850, 'TABASCO ROUGE GM 350 ML', 303, 14, 17.06),
#  (444, 8855, 'TABASCO ROUGE PM 60 ML', 303, 14, 3.68),
#  (445, 8856, 'TABASCO VERT 57ML', 303, 14, 3.64),
#  (446, 8860, 'SAUCE BARBECUE CALIFORNIA 970 ML', 303, 309, 6.1),
#  (447, 8870, 'SAUCE PIMENTO CHICKEN SWEET 800G', 303, 4, 3.98),
#  (448, 8872, 'SAUCE CURRY CALIFORNIA 970 ML', 303, 309, 7.49),
#  (449, 8873, 'SAUCE CURRY 950 ML COLONA', 303, 309, 3.78),
#  (450, 8874, 'SAUCE PITTA KEBAB 950 ML COLONA', 303, 309, 3.82),
#  (451, 8875, 'SAUCE PITTA KEBAB SEAU 5L COLONA', 303, 147, 16.32),
#  (452, 8876, 'SAUCE KEBAB CALIFORNIA 970 ML', 303, 309, 6.89),
#  (453, 8877, 'SAUCE BEARNAISE 950 ML COLONA', 303, 309, 4.27),
#  (454, 8878, 'SAUCE ALGERIENNE 950 ML COLONA', 303, 309, 3.84),
#  (455, 8879, 'SAUCE MAROCAINE 850 G COLONA', 303, 309, 3.87),
#  (456, 8880, 'AROME PATRELLE  1 L', 303, 4, 13.29),
#  (457, 8881, 'SAUCE ALGERIENNE - SEAU 5L', 303, 147, 18.13),
#  (458, 8882, 'SAUCE SAMOURAI COLONA - SEAU 5L', 303, 147, 16.47),
#  (459, 8885, 'VIANDOX 830ML', 303, 4, 8.52),
#  (460, 8890, "SAUCE SALSA 2 L UNCLE BEN'S", 303, 2, 14.21),
#  (461, 8891, "SAUCE CHILI  2.3 K BEN' S", 303, 2, 16.23),
#  (462, 8892, 'SAUCE CHILI HOT 793 G', 303, 2, 6.05),
#  (463, 8893, "SAUCE AIGRE DOUCE UNCLE BEN'S-2.3KG", 303, 2, 18.77),
#  (464, 8894, 'SAUCE BARBECUE CLASSIC FOODS- 3.7L', 303, 2, 19.09),
#  (465, 8895, 'SAUCE TACO SALSA AMIGOS - 2.05KG', 303, 2, 15.42),
#  (466, 8900, "SAUCE BARBECUE UNCLE BEN'S - 2,51 KG", 303, 2, 22.1),
#  (467, 8902, 'CHEDDAR CHEESE SAUCE 1.42 KG', 303, 468, 7.94),
#  (468, 8924, 'SAUCE ROQUEFORT CHEF - 1L', 303, 163, 12.17),
#  (469, 8925, 'SAUCE BEARNAISE CHEF', 303, 58, 20.13),
#  (470, 8930, 'ROUILLE  4/4', 303, 58, 8.9),
#  (471, 8931, 'ROUILLE POT 470GR', 303, 58, 6.64),
#  (472, 8950, 'SAUCE BEARNAISE COLONA- POT 3L', 303, 2, 12.49),
#  (473, 8951, 'SAUCE BEARNAISE AMORA - SEAU 2.7KG', 303, 147, 17.82),
#  (474, 8960, 'SAUCE TARTARE SEAU 2.8 KG', 303, 147, 11.61),
#  (475, 8962, 'ASSAIS.POUR TARTARE BOEUF MAILLE- 1.2KG', 303, 77, 18.4),
#  (476, 8966, 'SAUCE REDHOT ORIGINAL 14.8 CL', 303, 14, 2.23),
#  (477, 8968, 'SAUCE TERIYAKI  250ML KIKOMAN', 303, 14, 4.44),
#  (478, 8969, 'SAUCE TERIYAKI 975 ML', 303, 14, 19.95),
#  (479, 8970, 'SAUCE BIGGYBURGER POT 3L', 303, 2, 12.37),
#  (480, 8971, 'SAUCE YAKITORI 1 L', 303, 14, 14.76),
#  (481, 8972, 'SAUCE TERIYAKI BBQ 250ML KIKOMAN', 303, 14, 4.4),
#  (482, 9000, 'BOUILLON DE LEGUMES 1.2 KG KNORR', 483, 58, 15.15),
#  (483, 9001, 'BOUILLON DE POULE PATE 1 KG KNORR', 483, 58, 18.92),
#  (484, 9010, 'FONDS BRUN LIE 1/2 GLACE MAGGI', 483, 58, 19.98),
#  (485, 9015, 'FONDS BRUN LIE KNORR 750 G', 483, 58, 11.02),
#  (486, 9016, 'FOND BRUN LIE CHEF- 600G', 483, 58, 12.23),
#  (487, 9020, 'JUS DE VEAU LIE 1.2 KG  CHEF', 483, 58, 19.36),
#  (488, 9021, 'FOND DE VEAU PREMIUM 640G- CHEF', 483, 58, 24.82),
#  (489, 9023, 'ASIAN - CONCENTRÉ LIQUIDE 980ML- CHEF', 483, 4, 20.55),
#  (490, 9030, 'FUMET DE POISSON 900G CHEF', 483, 58, 22.9),
#  (491, 9031, 'VELOUTE  LEGUMES BRICK 6 X 1L POTAGERE', 483, 370, 13.0),
#  (492, 9034, 'FUMET DE POISSON PREMIUM 630 G - CHEF', 483, 58, 23.24),
#  (493, 9040, 'FUMET DE CRUSTACES 900G CHEF', 483, 58, 30.49),
#  (494, 9050, 'COURT BOUILLON MAGGI', 483, 58, 22.86),
#  (495, 9060, 'BOUILLON DE VOLAILLE 1.4 KG MAGGI', 483, 58, 18.97),
#  (496, 9065, 'BOUILLON DE BOEUF 1KG KNORR', 483, 58, 16.42),
#  (497, 9070, 'FONDS BLANC VOLAILLE CHEF - 800G', 483, 58, 17.24),
#  (498, 9080, 'FONDS BRUN CLAIR CHEF- 800G', 483, 58, 15.42),
#  (499, 9090, 'ROUX BLANC CHEF - 1KG', 483, 58, 9.47),
#  (500, 9100, 'SAUCE BEURRE BLANC CHEF-1.02 KG', 483, 58, 21.59),
#  (501, 9114, 'SAUCE MARCHAND DE VIN KNORR', 483, 58, 16.92),
#  (502, 9200, 'GELEE MAGGI - 750G / 15 L', 483, 58, 14.87),
#  (503, 9240, 'FONDS BLANC VEAU LIE CHEF- 800G', 483, 58, 25.14),
#  (504, 9255, 'POT AU FEU KNORR 1.1 KG', 483, 58, 17.83),
#  (505, 9300, 'JUS DE POULET CHEF FLOCON 600 G', 483, 58, 22.57),
#  (506, 9310, 'JUS AGNEAU FLOCON CHEF - 600G', 483, 58, 28.79),
#  (507, 9320, 'JUS DE CANARD CHEF FLOCON - 600G', 483, 58, 27.05),
#  (508, 9330, 'JUS DE BOEUF FLOCON CHEF- 600G', 483, 58, 18.83),
#  (509, 9335, 'KUBOR BTE 1.425 KG', 483, 58, 16.67),
#  (510, 9340, 'FONDS DE GIBIER 500G CHEF', 483, 58, 21.64),
#  (511, 10010, 'OLIVES NOIRES COQUILLOS SEAU 5 KG', 512, 147, 16.15),
#  (512, 10011, 'OLIVES NOIRES COQUILLOS SEAU 2.5 KG', 512, 147, 8.08),
#  (513, 10020, 'OLIVES CASSEES PIMENTEES SEAU 2.5 KG', 512, 147, 9.99),
#  (514, 10021, 'OLIVES TAILLADEES VIOLETTES 10 KG', 512, 147, 36.0),
#  (515, 10022, 'OLIVES TAILLADEES VIOLETTES SEAU 5KG', 512, 147, 17.85),
#  (516, 10026, 'OLIVES VERTES DENOYAUTEES SEAU 2.5KG', 512, 147, 11.75),
#  (517, 10066, 'OLIVES NOIRES GRECQUES DENOY. SEAU 2.5KG', 512, 147, 19.9),
#  (518, 10067, 'OLIVES GRECQUES ENTIERES SEAU 2.5KG', 512, 147, 12.5),
#  (519, 10070, 'OLIVES VERTES RONDELLES 3/1', 512, 58, 9.75),
#  (520, 10110, 'OLIVES NOIRES DENOYAUTEES 5/1', 512, 58, 6.44),
#  (521, 10111, 'OLIVES NOIRES DENOYAUTEES 4/4', 512, 58, 1.9),
#  (522, 10120, 'OLIVES NOIRES ENTIERES 4/4', 512, 58, 1.54),
#  (523, 10130, 'OLIVES NOIRES RONDELLES 3/1', 512, 58, 5.59),
#  (524, 10210, 'OLIVES VERTES DENOYAUTEES  5/1', 512, 58, 6.9),
#  (525, 10211, 'OLIVES VERTES DENOYAUTEES 4/4', 512, 58, 2.19),
#  (526, 11000, 'SUPER PIZZA 5/1 ARDITA', 527, 58, 4.18),
#  (527, 11001, 'POLPA FINE 5/1 ARDITA', 527, 58, 3.97),
#  (528, 11002, 'TOMATE CONCASSEE 5/1 RODOLFI', 527, 58, 4.39),
#  (529, 11010, 'SAUCE TOMATE AROMATISEE 5/1  MUTTI', 527, 58, 5.89),
#  (530, 11015, 'TOMATE AROMATISEE 5/1 VICTORIA', 527, 58, 4.49),
#  (531, 11020, 'TOMATES PEL.CONCASSEES 5/1  MUTTI', 527, 58, 5.38),
#  (532, 11021, 'TOMATES PEL.CONC.CUBES 5/1 VICT. (NOIRE)', 527, 58, 4.83),
#  (533, 11022, 'TOMATES PEL.CONC.4/4  MUTTI', 527, 58, 1.62),
#  (534, 11025, 'TOMATES PEL.CONC 5/1  VICT.(BLEUE)', 527, 58, 3.67),
#  (535, 11026, 'TOMATES POLPA 5/1  MUTTI', 527, 58, 5.86),
#  (536, 11040, 'TOMATES CONCASSEES 4/4  VICTORIA', 527, 58, 0.99),
#  (537, 11041, 'TOMATES PELEES ENT. 3/1  MUTTI', 527, 58, 4.2),
#  (538, 11042, 'TOMATES PELEES ENTIERES 4/4  MUTTI', 527, 58, 1.88),
#  (539, 11043, 'TOMATES PELEES ENT. 5/1  MUTTI', 527, 58, 6.32),
#  (540, 11044, 'TOMATES PELEES ENTIERES 4/4 VICTORIA', 527, 58, 0.9),
#  (541, 11045, 'TOMATES PELEES ENTIERES 3/1- CIRIO', 527, 58, 3.56),
#  (542, 11050, 'PUREE TOMATE PASSATA NAT.700 G  MUTTI', 527, 4, 1.91),
#  (543, 11062, 'CONCENTRE TOMATE 4/4 MUTTI', 527, 58, 3.33),
#  (544, 11063, "SAUCE TOMATE PIZZA 5/1 MARTIN'S", 527, 58, 4.59),
#  (545, 11072, 'CONCENTRE TOMATE 4/4  IMPORT', 527, 58, 1.69),
#  (546, 11073, 'CONCENTRE DE TOMATE 1/2', 527, 58, 1.3),
#  (547, 11075, 'CONCENTRE DE TOMATE TUBE 150G', 527, 345, 1.37),
#  (548, 11080, 'GASPACHO 1L', 527, 549, 4.4),
#  (549, 11095, 'TARTUFATA TERRE FRANCESCANE BOCAL 500G', 527, 374, 12.99),
#  (550, 11096, 'CREME DE CHAMPIGNON A LA TRUFFE 1/2', 527, 58, 10.3),
#  (551, 11097, 'LAMELLES DE TRUFFES 500G BOCAL', 527, 374, 78.15),
#  (552, 11098, "CREME D'ARTICHAUT 4/4", 527, 58, 8.71),
#  (553, 11099, 'BRISURE DE TRUFFE NOIRE 500G', 527, 374, 72.0),
#  (554, 11100, 'CHAMPIGNONS HOTEL 5/1', 527, 58, 8.38),
#  (555, 11101, 'SALSA TARTUFATA REALE 500G', 527, 374, 28.84),
#  (556, 11102, 'TARTUFATA CATERING 500 G', 527, 374, 10.2),
#  (557, 11103, 'CARPACCIO DE TRUFFES 500 G BOCAL', 527, 374, 67.61),
#  (558, 11104, 'SALSA TARTUFATA 200G', 527, 374, 10.6),
#  (559, 11105, 'CREME TRUFFE BLANCHE GRANA PADANO 200 G', 527, 374, 13.48),
#  (560, 11106, 'JUS DE TRUFFE NOIRE 200ML', 527, 4, 36.06),
#  (561, 11110, 'CHAMPIGNONS HOTEL 4/4', 527, 58, 1.77),
#  (562, 11120, 'GARNITURE FORESTIERE 4/4', 527, 58, 2.33),
#  (563, 11130, 'LACTAIRES 4/4', 527, 58, 6.99),
#  (564, 11160, 'CEPES SECS 500 G', 527, 565, 21.82),
#  (565, 11161, 'CEPES ET BOLETS SECS 500 G', 527, 565, 11.96),
#  (566, 11162, 'CHAMPIGNONS TROMP. DES MAURES 500G', 527, 565, 22.93),
#  (567, 11163, 'GIROLLES DESHYDRATEES 500G', 527, 565, 49.9),
#  (568, 11165, 'CHAMPIGNONS NOIRS TUBO 500G', 527, 565, 10.93),
#  (569, 11168, 'MELANGE FORESTIER SEC 500 G', 527, 565, 10.1),
#  (570, 11170, 'CHAMPIGNONS FRAIS - CAISSE DE 3KG', 527, 71, 3.89),
#  (571, 11171, 'CITRON CAISSE 1.5 KG', 527, 90, 3.55),
#  (572, 11172, 'ORANGE FILET 2KG', 527, 468, 3.73),
#  (573, 11173, 'CITRON VERT KG', 527, 34, 3.33),
#  (574, 11174, 'MENTHE BOUQUET X5', 527, 468, 4.99),
#  (575, 11175, 'COURGETTES 2KG', 527, 468, 4.79),
#  (576, 11180, 'MORILLES EXTRA 400 G', 527, 565, 179.0),
#  (577, 11185, 'MORILLONS  500 G', 527, 565, 108.22),
#  (578, 11201, "CREME D'ARTICHAUT 4/4 GIO&CO", 527, 58, 10.5),
#  (579, 11205, "COEUR D'ARTICHAUT QUARTIER - MORCEAU 3/1", 527, 58, 8.84),
#  (580, 11210, "COEURS D'ARTICHAUT 4/4", 527, 58, 2.96),
#  (581, 11260, "FONDS D'ARTICHAUT 4/4", 527, 58, 3.22),
#  (582, 11300, 'HARICOTS VERTS TF 5/1', 527, 58, 5.39),
#  (583, 11301, 'HARICOTS VERTS TF 4/4', 527, 58, 1.35),
#  (584, 11305, 'HARICOTS BEURRE  TF 4/4', 527, 58, 2.02),
#  (585, 11320, 'HARICOTS BLANCS 5/1', 527, 58, 4.99),
#  (586, 11321, 'HARICOTS BLANCS 4/4', 527, 58, 1.14),
#  (587, 11330, 'HARICOTS ROUGES 5/1', 527, 58, 5.24),
#  (588, 11331, 'HARICOTS ROUGES 4/4', 527, 58, 1.44),
#  (589, 11340, 'FLAGEOLETS VERTS FINS 5/1', 527, 58, 6.77),
#  (590, 11341, 'FLAGEOLETS VERTS 4/4', 527, 58, 1.66),
#  (591, 11350, 'HARICOTS LINGOTS BLANCS - 500 G', 527, 592, 2.05),
#  (592, 11351, 'HARICOT COCO BLANC 1KG', 527, 592, 3.47),
#  (593, 11352, 'HARICOTS LINGOTS BLANCS - 1 KG', 527, 592, 4.1),
#  (594, 11400, 'PETITS POIS TF 5/1', 527, 58, 5.89),
#  (595, 11401, 'PETITS POIS TF 4/4', 527, 58, 1.5),
#  (596, 11420, 'PETITS POIS CAROTTES T F 5/1', 527, 58, 5.73),
#  (597, 11421, 'PETITS POIS TF CAROTTES 4/4', 527, 58, 1.37),
#  (598, 11422, 'SALSIFIS COUPES 5/1', 527, 58, 9.79),
#  (599, 11430, 'MACEDOINE DE LEGUMES 5/1', 527, 58, 5.56),
#  (600, 11431, 'MACEDOINE DE LEGUMES 4/4', 527, 58, 1.4),
#  (601, 11451, 'POMME DE TERRE 4/4', 527, 58, 1.97),
#  (602, 11500, 'BETTERAVES EN DES 5/1', 527, 58, 3.84),
#  (603, 11501, 'BETTERAVE EN DES 4/4', 527, 58, 1.36),
#  (604, 11510, 'CELERIS RAVES 5/1', 527, 58, 4.18),
#  (605, 11520, 'CAROTTES RAPEES 5/1', 527, 58, 4.37),
#  (606, 11521, 'POIS CASSES VERTS 500G', 527, 592, 1.81),
#  (607, 11525, 'CAROTTES RONDELLES 5/1', 527, 58, 6.52),
#  (608, 11526, 'CAROTTES JEUNES 5/1', 527, 58, 5.12),
#  (609, 11530, 'MAIS GRAIN  3/1 IMPORT', 527, 58, 4.4),
#  (610, 11531, 'MAIS GRAIN 4/4 IMPORT', 527, 58, 1.38),
#  (611, 11532, 'MAIS 1/2', 527, 58, 0.9),
#  (612, 11533, 'MAIS EPIS JEUNE 1/2', 527, 58, 0.92),
#  (613, 11534, 'MAIS EPIS GROS 5/4', 527, 58, 2.74),
#  (614, 11538, 'MAIS EPI JEUNE 3/1', 527, 58, 5.19),
#  (615, 11540, 'POIVRONS 3 COULEURS 5/1', 527, 58, 7.65),
#  (616, 11541, 'POIVRONS ROUGES 3/1', 527, 58, 5.58),
#  (617, 11542, 'POIVRONS ROUGES 4/4', 527, 58, 2.14),
#  (618, 11545, 'POIVRONS ROUGES PIQUILLOS BTE 470 G', 527, 58, 6.29),
#  (619, 11546, 'OIGNON EMINCES 5/1', 527, 58, 11.55),
#  (620, 11550, 'LENTILLES 5/1', 527, 58, 4.31),
#  (621, 11551, 'LENTILLES 4/4', 527, 58, 1.59),
#  (622, 11554, 'LENTILLES VERTES - SAC 5 KG', 527, 35, 8.79),
#  (623, 11556, 'LENTILLES VERTES - 500 G', 527, 592, 2.05),
#  (624, 11557, 'LENTILLES BLONDES 500 G', 527, 592, 1.46),
#  (625, 11560, 'POIS CHICHES 5/1', 527, 58, 4.38),
#  (626, 11561, 'POIS CHICHES 4/4', 527, 58, 1.16),
#  (627, 11566, 'POIS CHICHE SECS  40/42 - SAC 5 KG', 527, 35, 15.26),
#  (628, 11567, 'POIS CHICHE SECS 500 G', 527, 592, 2.44),
#  (629, 11570, 'POIREAUX BLANCS 3/1', 527, 58, 4.26),
#  (630, 11580, 'OIGNONS PREFRITS  5/1', 527, 58, 6.47),
#  (631, 11581, 'OIGNONS FRITS 500G - CLASSIC FOODS', 527, 47, 3.99),
#  (632, 11582, 'OIGNON RISSOLE SAC- 1 KG', 527, 47, 9.69),
#  (633, 11590, 'ENDIVES 5/1', 527, 58, 6.79),
#  (634, 11595, 'EPINARD BRANCHE 5/1', 527, 58, 5.04),
#  (635, 11596, 'EPINARD BRANCHE 4/4', 527, 58, 1.69),
#  (636, 11610, 'ASPERGES GROSSES 17-24 2/1', 527, 58, 4.59),
#  (637, 11611, 'ASPERGES PIC NIC 1/4', 527, 58, 1.39),
#  (638, 11613, "ASPERGES 4/4 MARTIN'S", 527, 58, 3.15),
#  (639, 11620, 'COEURS DE PALMIER 4/4', 527, 58, 3.18),
#  (640, 11626, 'POUSSES DE HARICOT MUNGO 4/4', 527, 58, 1.63),
#  (641, 11628, 'POUSSES DE BAMBOU 3/4', 527, 58, 3.8),
#  (642, 11629, 'POUSSES DE BAMBOU 3/1', 527, 58, 6.39),
#  (643, 11645, 'POMME DE TERRE LAMELLE - 2 KG', 527, 35, 3.12),
#  (644, 11650, 'POMME DE TERRE RONDE S/V - 2.K', 527, 35, 4.64),
#  (645, 11701, "AUBERGINES GRILLEES A L'HUILE - BQ 950G", 527, 49, 8.73),
#  (646, 11702, 'COURGETTES GRILLEES A L HUILE 950G', 527, 49, 9.13),
#  (647, 11708, 'TARTARE DE TOMATES 1KG', 527, 71, 11.99),
#  (648, 11710, "TOMATES SECHEES A L'HUILE - BQ 950G", 527, 49, 7.71),
#  (649, 11715, 'TOMATES CONFITES 1.9K', 527, 147, 23.61),
#  (650, 11725, 'CHAMPIGNONS SANGUINS - SEAU 3.5 KG', 527, 147, 38.86),
#  (651, 11730, 'ARTICHAUTS GRILLES  HUILE - BQ 950 G', 527, 49, 12.02),
#  (652, 11735, 'ARTICHAUTS COEURS COUPES SEAU 3 KG', 527, 147, 27.49),
#  (653, 11742, "POIVRONS GRILLES A L'HUILE - BQ 950G", 527, 49, 8.69),
#  (654, 11746, 'POIVRONS LAMELLES J&R SEAU 3 KG', 527, 147, 18.57),
#  (655, 11770, 'INVOLTINI SPECK RICOTTA BREB. 1KG', 527, 58, 15.58),
#  (656, 11800, 'QUENELLE BROCHET 5/1', 527, 58, 14.83),
#  (657, 11810, 'QUENELLE VOLAILLE 5/1', 527, 58, 12.56),
#  (658, 11855, 'CHOUCROUTE BRASSERIE 5/1', 527, 58, 8.89),
#  (659, 11895, 'ESCARGOTS BOURG. 4/4 - 8 DZ', 527, 58, 12.9),
#  (660, 11900, 'RATATOUILLE 5/1', 527, 58, 4.85),
#  (661, 11910, 'PIPERADE 5/1', 527, 58, 8.16),
#  (662, 11920, 'FEUILLES DE VIGNE 2/1', 527, 58, 7.39),
#  (663, 11940, 'TABOULE GARNITURE 5/1', 527, 58, 8.46),
#  (664, 11941, 'SALADE TABOULE ORIENT 2.5 KG', 527, 49, 7.0),
#  (665, 11950, 'MARRONS ENTIERS 4/4', 527, 58, 5.6),
#  (666, 111102, 'TRUFFE ENTIERE KG', 527, 34, 940.0),
#  (667, 12100, 'POIRES AU SIROP 5/1', 668, 58, 6.0),
#  (668, 12101, "POIRES SIROP 4/4 IMPORT MARTIN'S", 668, 58, 1.99),
#  (669, 12110, 'POIRES SIROP 4/4 ST MAMET', 668, 58, 2.78),
#  (670, 12211, 'ABRICOT SIROP 4/4 IMPORT', 668, 58, 1.54),
#  (671, 12300, 'PECHES SIROP 5/1 VICTORIA', 668, 58, 5.66),
#  (672, 12301, 'PECHE SIROP 4/4 IMPORT', 668, 58, 1.26),
#  (673, 12310, 'PECHES SIROP 4/4  ST MAMET', 668, 58, 2.35),
#  (674, 12400, 'ANANAS T. ENTIERES  3/1', 668, 58, 5.71),
#  (675, 12405, 'ANANAS MORCEAUX 3/1', 668, 58, 6.35),
#  (676, 12410, 'ANANAS T.E. 3/4', 668, 58, 1.37),
#  (677, 12412, 'ANANAS MORCEAUX (BRISÉS) 3/4', 668, 58, 1.39),
#  (678, 12415, 'ANANAS T.E 4/4', 668, 58, 1.99),
#  (679, 12450, 'COCKTAIL DE FRUITS 5/1 VICTORIA', 668, 58, 7.65),
#  (680, 12460, 'SALADE DE FRUITS FRAIS  SEAU 3 KG', 668, 147, 14.99),
#  (681, 12461, 'SEGMENT DE PAMPLEMOUSSE 1KG', 668, 147, 11.0),
#  (682, 12462, 'SEGMENT DE PAMPLEMOUSSE SEAU 3KG', 668, 147, 14.44),
#  (683, 12463, "SEGMENT D'ORANGE SEAU 3KG", 668, 147, 14.44),
#  (684, 12465, 'COCKTAIL DE FRUITS 4/4', 668, 58, 2.1),
#  (685, 12480, 'PAMPLEMOUSSE SEGMENTS 3/1', 668, 58, 7.75),
#  (686, 12500, 'BIGAREAUX DENOYAUTES 4/4', 668, 58, 2.96),
#  (687, 12520, 'AMARENA 3/1', 668, 58, 22.22),
#  (688, 12521, 'AMARENA CERISE 4/4', 668, 58, 10.01),
#  (689, 12540, 'LITCHEES 3/4', 668, 58, 2.23),
#  (690, 12541, 'LITCHEES 3/1', 668, 58, 13.1),
#  (691, 12580, 'QUETCHES DENOYAUTEES 2/1', 668, 58, 5.7),
#  (692, 12600, 'COMPOTE DE POMME 5/1', 668, 58, 6.34),
#  (693, 12601, 'COMPOTE DE POMME PATISSIERE 5/1', 668, 58, 7.94),
#  (694, 12610, 'COMPOTE DE POMME 4/4', 668, 58, 1.43),
#  (695, 12615, 'COMPOTE DE POMME X120', 668, 29, 28.38),
#  (696, 12616, 'COMPOTE DE POMME 90GX72 GOURDES', 668, 29, 53.08),
#  (697, 12617, 'COMPOTE DE POMME 90GX24 GOURDES - ANDROS', 668, 29, 14.12),
#  (698, 12652, 'CREME DE MARRON  4/4', 668, 58, 5.57),
#  (699, 12653, 'CREME MARRON VANILLE 5/1', 668, 58, 24.64),
#  (700, 12655, 'CREME DE MARRON FAUGIER  4/4', 668, 58, 6.2),
#  (701, 13010, 'NOIX DE COCO RAPEE 1 KG', 702, 47, 5.08),
#  (702, 13020, 'PIGNONS DE PIN 1KG', 702, 47, 39.93),
#  (703, 13030, 'RAISINS SECS BLONDS 1 KG', 702, 47, 5.75),
#  (704, 13035, 'RAISINS SULTAMINE BRUN  1 KG', 702, 47, 3.54),
#  (705, 13040, 'CERNEAUX DE NOIX ARL/INV. 1 KG', 702, 47, 11.71),
#  (706, 13045, 'CERNEAUX DE NOIX EXTRA MOITIE 1 KG', 702, 47, 16.03),
#  (707, 13050, 'PRUNEAUX DENOYAUTES 500G', 702, 47, 3.95),
#  (708, 13051, 'FIGUES SECHES 500G', 702, 47, 4.08),
#  (709, 13053, 'PRUNEAUX GEANT ENTIER 1 KG', 702, 47, 7.86),
#  (710, 13054, 'PRUNEAUX DENOYAUTES 1KG', 702, 47, 6.07),
#  (711, 13060, 'NOISETTES POUDRE BRUTE 1 KG', 702, 47, 36.16),
#  (712, 13061, 'NOISETTE HACHEE BLANCHIE 1 KG', 702, 47, 13.9),
#  (713, 13070, 'NOISETTES CRUES DECORT 1 KG', 702, 47, 15.15),
#  (714, 13071, 'NOISETTES EMONDEES ENT. 1 KG', 702, 47, 29.65),
#  (715, 13080, 'ABRICOTS SECS  1 KG', 702, 47, 4.88),
#  (716, 13100, 'AMANDES EFFILEES  1 KG', 702, 47, 14.1),
#  (717, 13105, 'AMANDES ENTIERES AVEC PEAU 1 KG', 702, 47, 15.99),
#  (718, 13110, 'AMANDES POUDRE 1 KG', 702, 47, 12.2),
#  (719, 13120, 'AMANDES EN BATONNETS  1 KG', 702, 47, 28.79),
#  (720, 13130, 'AMANDES HACHEES  1 KG', 702, 47, 12.65),
#  (721, 13140, 'AMANDES EMONDEES  1 KG', 702, 47, 18.06),
#  (722, 13151, 'NOIX DE PECAN 1KG', 702, 47, 33.96),
#  (723, 13152, 'NOIX DE CAJOU - SAC 1 KG', 702, 47, 19.72),
#  (724, 13155, 'MAIS POP CORN 1KG', 702, 47, 3.42),
#  (725, 13161, 'PISTACHES VERTE DECORTIQUEES 1KG', 702, 47, 46.14),
#  (726, 13165, 'PISTACHES HACHEES  1KG', 702, 47, 49.26),
#  (727, 13700, "CACAHUETTES GRILLEES KREEK'S  1 KG", 702, 47, 6.39),
#  (728, 13740, 'MELANGE EXOTIQUE 1KG', 702, 47, 9.58),
#  (729, 23555, 'AMANDES ENROB. DE CACAO X200', 702, 29, 14.32),
#  (730, 14100, 'MIEL LIQUIDE 1 KG', 731, 147, 6.58),
#  (731, 14110, 'MIEL A LA TRUFFE 150 G', 731, 71, 8.7),
#  (732, 14130, 'MIEL LIQUIDE SQUEEZE 500 G', 731, 309, 5.44),
#  (733, 14150, 'MIEL 20 G X 120 ALU', 731, 29, 26.0),
#  (734, 14151, 'MIEL POT VERRE 30G X 60 BM', 731, 29, 39.54),
#  (735, 14200, 'CONFITURES ASSORT. COUP ALU X 120', 731, 29, 17.41),
#  (736, 14201, 'CONFITURES ASSORT. PLAST 30GX120', 731, 29, 8.95),
#  (737, 14211, 'CONFITURE FRAISE PLAST 30GX120', 731, 29, 9.84),
#  (738, 14212, 'CONFITURE ABRICOT PLAST 30GX120', 731, 29, 9.84),
#  (739, 14214, 'GELEE DE GROSEILLE - BQ PL X 100', 731, 29, 13.54),
#  (740, 14301, 'CONFITURE FRAISE 1 KG', 731, 77, 3.39),
#  (741, 14302, 'CONFITURE MYRTILLE 1KG', 731, 77, 6.84),
#  (742, 14303, 'CONFITURE DE LAIT 1.1 KG AMIGOS', 731, 468, 13.59),
#  (743, 14305, 'CONFITURE ABRICOT POT VERRE 30GX60 B.M.', 731, 29, 23.15),
#  (744, 14306, 'CONFITURE FRAISE POT VERRE 30GX60 B.M.', 731, 29, 24.15),
#  (745, 14307, 'CONFITURE MYRTILLE POT VERRE 30GX60 B.M.', 731, 29, 29.66),
#  (746, 14311, "CONFITURE D'ABRICOT 1 KG", 731, 77, 3.29),
#  (747, 14313, 'CONFITURE ORANGE P.VERRE 30GX60 B.M.', 731, 29, 24.42),
#  (748, 14316, 'CONFITURE FRAMBOISE POT VERRE 30GX60 B.M', 731, 29, 29.66),
#  (749, 14317, 'CONFITURE CERISE POT VERRE 30GX60 B.M.', 731, 29, 25.03),
#  (750, 14318, 'GELEE FRAMB/GROSEILLE PV 30GX60 B.M.', 731, 29, 27.72),
#  (751, 14319, 'CONFITURES ASSORT. PV 30GX60  B.M.', 731, 29, 26.1),
#  (752, 14320, 'CONFITURE FRAISE COUP ALU 20G X 120 ST M', 731, 29, 18.5),
#  (753, 14321, 'CONFITURE FRAMBOISE 1 KG', 731, 77, 5.59),
#  (754, 14325, 'CONFITURE ABRICOT COUP ALU X 120', 731, 29, 17.54),
#  (755, 14330, 'GELEE DE GROSEILLE 1 KG', 731, 77, 3.52),
#  (756, 14335, 'CONFITURE ORANGE ALU X 120', 731, 29, 16.31),
#  (757, 14340, 'CONFITURE FRAMBOISE 370 G BM', 731, 77, 3.14),
#  (758, 14349, 'CONFITURE ORANGES AMERES 370 G BM', 731, 77, 2.36),
#  (759, 14350, 'CONFITURE FIGUE 370 G BM', 731, 77, 2.28),
#  (760, 14351, 'CONFITURE ABRICOT 370 G BM', 731, 77, 2.11),
#  (761, 14352, 'CONFITURE FRAISE 370 G BM', 731, 77, 2.61),
#  (762, 14353, 'GELEE DE GROSEILLES 450 G', 731, 77, 1.85),
#  (763, 14354, 'CONFITURE DE MYRTILLES 370 G BM', 731, 77, 2.85),
#  (764, 14355, 'CONFITURE DE CERISES GRIOTTES 370G BM', 731, 77, 2.98),
#  (765, 14400, 'CONFITURE FRAISE 5/1', 731, 58, 17.7),
#  (766, 999912, 'CONFITURE FIGUES P/V 28G X24', 731, 29, 11.93),
#  (767, 15010, 'BIGAREAUX CONFITS 1 KG', 768, 58, 9.43),
#  (768, 15015, 'PATE A PISTACHE 1KG', 768, 58, 32.99),
#  (769, 15020, 'FRUITS CUBES TRICOLORES  1 KG', 768, 58, 6.84),
#  (770, 15060, 'PRALINE EN GRAINS BARRY 1KG', 768, 58, 16.9),
#  (771, 15061, 'PRALINE AMANDE/NOISETTE BARRY SEAU 1KG', 768, 58, 18.35),
#  (772, 15100, 'NAPPAGE BLOND SEAU 7 KG', 768, 147, 16.28),
#  (773, 15110, 'NAPPAGE BLOND 900G', 768, 147, 3.92),
#  (774, 15150, 'NAPPAGE ROUGE SEAU 6.5 KG', 768, 147, 16.74),
#  (775, 15160, 'NAPPAGE ROUGE 1 KG', 768, 147, 4.6),
#  (776, 15200, 'NAPPAGE CARAMEL ANCIENNE 1 L VAHINE', 768, 4, 8.9),
#  (777, 15205, 'SAUCE DESS. CARAMEL DOCELLO 1L NESTLE', 768, 4, 5.78),
#  (778, 15215, 'SAUCE DESS. CHOCOLAT DOCELLO 1L NESTLE', 768, 4, 6.19),
#  (779, 15225, 'SAUCE DESSERT CAFE DOCELLO NESTLE', 768, 4, 7.43),
#  (780, 15230, 'SAUCE FRUITS ROUGES DOCELLO NESTLE', 768, 4, 6.91),
#  (781, 15231, 'SAUCE DESSERT FRAISE DOCELLO NESTLE', 768, 4, 6.53),
#  (782, 15232, 'SCE DESS SENSATION PISTACHE NESTLE DOCE', 768, 14, 19.03),
#  (783, 15233, 'SCE DESS SENSATION CACAHUÈTE NESTLE DOCE', 768, 14, 14.86),
#  (784, 15234, 'SCE DESS SENSATION CHOCONUT NESTLE DOCE', 768, 14, 16.54),
#  (785, 15235, 'SCE DESS SENSATION NOISETTE NESTLE DOCE', 768, 14, 16.53),
#  (786, 15280, 'SAUCE PROFITEROLLES 3/1 NESTLE', 768, 58, 23.4),
#  (787, 15300, 'MOUSSE CHOCOLAT NESTLE 1.5 KG', 768, 58, 16.02),
#  (788, 15302, 'MOUSSE CHOCOLAT LAIT 54 G X 4', 768, 789, 0.88),
#  (789, 15321, 'MOUSSE NOUGAT PREP ALSA 1 KG', 768, 58, 18.11),
#  (790, 15330, 'CREME BRULEE/RENV. DESHYDRATEE NESTLE', 768, 58, 9.97),
#  (791, 15354, 'PANNA COTTA 800G ALSA', 768, 58, 10.55),
#  (792, 15360, 'TIRAMISU PREPARATION 490G ALSA', 768, 58, 11.27),
#  (793, 15400, 'CARAMEL LIQUIDE 1.25 KG', 768, 4, 4.95),
#  (794, 15420, 'EXTRAIT DE CAFE 1L', 768, 4, 33.61),
#  (795, 15430, 'VANILLE AROME ARTIFICIEL 1 LITRE', 768, 4, 7.99),
#  (796, 15431, 'COLORANT ROUGE 50 CL SEBALCE', 768, 14, 16.23),
#  (797, 15432, 'COLORANT JAUNE OEUF 50 CL SEBALCE', 768, 14, 15.8),
#  (798, 15433, 'COLORANT VERT 50 CL SEBALCE', 768, 14, 14.53),
#  (799, 15434, 'COLORANT ALIMENTAIRE FLACON 35G X12', 768, 114, 17.87),
#  (800, 15445, "EAU DE FLEUR D'ORANGER 1 L", 768, 4, 3.19),
#  (801, 15450, 'VANILLE GOUSSES STE LUCIE - BT 50G', 768, 374, 52.59),
#  (802, 15460, 'AROME ORANGE 50CL', 768, 4, 19.41),
#  (803, 15505, 'PREP. GARNIT. FROID RICO 2.5 KG COMPLET', 768, 47, 10.5),
#  (804, 15510, 'CREME PATISSIERE CHAUD  MOENCH 1 KG', 768, 47, 6.99),
#  (805, 15515, 'CREME PATISSIERE A FROID 1 KG - COMPLET', 768, 47, 5.76),
#  (806, 15527, 'CREME PATISS. CHAUD 5KG MOENCH', 768, 47, 23.25),
#  (807, 15530, 'KREMFIX 750G ANCEL', 768, 58, 8.12),
#  (808, 15531, 'TANT POUR TANT BLANC 1KG', 768, 47, 18.0),
#  (809, 15540, 'GLUCOSE  POT 1 KG', 768, 58, 3.5),
#  (810, 15541, 'GLUCOSE SEAU X 7 KG', 768, 147, 26.27),
#  (811, 15545, 'FONDANT BLANC POT 1KG LEGAVE', 768, 147, 5.78),
#  (812, 15546, 'FONDANT BLANC SEAU 8 KG', 768, 147, 20.36),
#  (813, 15550, 'MAIZENA 700 G', 768, 58, 4.57),
#  (814, 15561, 'FECULE DE PDT 1 KG', 768, 47, 4.52),
#  (815, 15562, 'FECULE DE POMME DE TERRE 250G', 768, 592, 0.99),
#  (816, 15564, 'FECULE DE PDT SAC 5 KG', 768, 35, 10.08),
#  (817, 15570, 'GELATINE TITANE 200F 1 KG SEBALCE', 768, 58, 20.75),
#  (818, 15575, 'GELATINE FEUILLE BRONZE 1 KG', 768, 58, 33.19),
#  (819, 15580, 'GELATINE  PLAQUE OR 475G - 225 FEUILLES', 768, 58, 24.37),
#  (820, 15581, 'GELATINE  PLAQUES OR 1KG', 768, 58, 45.16),
#  (821, 15582, 'PATE A TARTINER SPECULOOS 720G', 768, 77, 6.71),
#  (822, 15586, 'NUTELLA 1KG - POT', 768, 77, 6.9),
#  (823, 15587, 'NUTELLA 3KG POT', 768, 77, 21.5),
#  (824, 15590, 'AGAR AGAR POUDRE 25G', 768, 47, 1.68),
#  (825, 15591, 'AGAR AGAR POT 330 ML-165G', 768, 77, 17.71),
#  (826, 15600, 'PALETS CHOCOLAT 44% CEMOI 5 KG', 768, 58, 22.93),
#  (827, 15605, 'CHOCOLAT COUV. BLANC 30 % PIST. 5 KG', 768, 58, 41.64),
#  (828, 15610, 'CHOC. COUV. LACTEE 32.5 % 5 KG CEMOI', 768, 58, 39.19),
#  (829, 15630, 'MICRO COPEAUX CHOCO/ NOIR 2.5KG - BARRY', 768, 58, 19.81),
#  (830, 15635, 'CHOCOLAT COUV.LABO 72%  PIST.5 KG', 768, 58, 54.93),
#  (831, 15640, 'CHOCOLAT COUV. 50% PALETS. CEMOI 5 KG', 768, 58, 25.73),
#  (832, 15645, 'CHOCOLAT NOIR 50 % MINI GOUTTE 6KG', 768, 58, 33.0),
#  (833, 15655, 'CHOCOLAT COUV. NOIR 55%  5 KG', 768, 58, 37.52),
#  (834, 15665, 'PALETS CHOCOLAT 64% CEMOI 5 KG', 768, 58, 40.27),
#  (835, 15688, 'NUTELLA BARQ 15GX120', 768, 29, 23.9),
#  (836, 15691, 'CACAO POUDRE PLEIN AROME  1KG BARRY', 768, 35, 10.32),
#  (837, 15710, 'VERMICELLES ARC EN CIEL - 1 KG', 768, 592, 8.99),
#  (838, 15711, 'VERMICELLES CHOCOLAT 1 KG', 768, 592, 8.99),
#  (839, 35948, 'COULIS EXOTIQUE PASSION 500ML SG', 768, 309, 5.47),
#  (840, 35949, 'COULIS DE FRUITS ROUGES SG 500ML', 768, 309, 5.64),
#  (841, 35950, 'PUREE DE FRAMBOISE POT 1KG SG', 768, 77, 8.9),
#  (842, 35951, 'PUREE DE MANGUE SG POT 1KG', 768, 77, 8.99),
#  (843, 35952, 'PUREE DE FRAISE SG POT 1KG', 768, 77, 7.38),
#  (844, 35953, 'PUREE DE PASSION POT 1KG SG', 768, 77, 10.2),
#  (845, 35954, "PUREE D'ABRICOT SG POT 1K", 768, 77, 5.84),
#  (846, 35956, 'PUREE DE POIRE  SG POT 1K', 768, 77, 6.93),
#  (847, 35957, 'CUBES DE MANGUE SACHET 1KG SG', 768, 47, 7.2),
#  (848, 35958, 'MANGUE EN CUBE SACHET 2.5KG SG', 768, 35, 17.99),
#  (849, 40120, "PATE D'AMANDE BL.33 % - 1KG", 768, 114, 16.9),
#  (850, 16115, 'THON ENTIER HUILE 4/4', 851, 58, 5.15),
#  (851, 16160, "SARDINE A L'HUILE 4/4", 851, 58, 5.68),
#  (852, 16200, 'THON AU NATUREL 3/1', 851, 58, 14.09),
#  (853, 16210, 'THON AU NATUREL 4/4', 851, 58, 5.7),
#  (854, 16211, 'THON AU NATUREL 1/6 - 133G', 851, 58, 1.42),
#  (855, 16212, 'THON NATUREL POCHE 600G', 851, 468, 4.46),
#  (856, 16410, 'FRUITS DE MER AU NATUREL - SEAU 4 KG', 851, 147, 32.33),
#  (857, 16411, 'FRUITS DE MER AUX LEGUMES - SEAU 4 KG', 851, 147, 43.9),
#  (858, 16415, 'COCKTAIL FRUIT DE MER NAT SEAU 1.5 KG', 851, 147, 14.94),
#  (859, 16432, 'CREVETTES 200/400 - POT 900 G', 851, 77, 17.79),
#  (860, 16500, 'BISQUE HOMARD 3/1 BEAUMOULIN', 851, 58, 11.76),
#  (861, 16501, 'BISQUE HOMARD LIEBIG 3/1', 851, 58, 17.34),
#  (862, 16511, 'BISQUE HOMARD LIEBIG 4/4', 851, 58, 6.37),
#  (863, 16550, 'SOUPE POISSON BEAUMOULIN 3/1', 851, 58, 9.39),
#  (864, 16555, 'SOUPE POISSON FRAICHE BLLE 1L', 851, 4, 21.73),
#  (865, 16561, 'SOUPE DE POISSONS 4/4 BEAUMOULIN', 851, 58, 3.81),
#  (866, 16610, "ANCHOIS FILETS A L'HUILE 4/4", 851, 58, 11.83),
#  (867, 16611, "F/ANCHOIS A L'HUILE D'OLIVE 4/4", 851, 58, 12.55),
#  (868, 16612, 'ANCHOIS FILETS HUILE MAROC 700 G BARQUET', 851, 49, 11.1),
#  (869, 16640, 'ANCHOIS AU SEL SEAU 5/1', 851, 147, 49.67),
#  (870, 16650, 'ANCHOIS MARINE 1 KG', 851, 49, 11.99),
#  (871, 16680, 'ANCHOIADE 1 KG', 851, 77, 14.79),
#  (872, 16700, 'HARENG FILET HUILE  BARQ 3 KG', 851, 49, 23.6),
#  (873, 16749, 'SURIMI BATONNET 250G', 851, 58, 2.29),
#  (874, 16750, 'SURIMI ROULEAU 2 KG', 851, 58, 13.3),
#  (875, 16753, 'SURIMI MIETTE 500 G', 851, 58, 5.64),
#  (876, 16800, 'CRABE CHAIR ET PATTES  121 G', 851, 58, 5.76),
#  (877, 16810, 'CRABE CHAIR 4/4', 851, 58, 14.6),
#  (878, 16910, 'SAUMON FUME. ATLANT. LE  KG', 851, 34, 25.88),
#  (879, 16911, 'SAUMON FUME TR 30GX30TR', 851, 34, 25.01),
#  (880, 16915, 'SAUMON FUME. ATLANT. EXTRA TR LE  KG', 851, 34, 36.96),
#  (881, 16920, 'SAUMON FRAIS FILET S/V - LE KG', 851, 34, 19.5),
#  (882, 16950, 'CHUTES DE SAUMON - POCHE DE 500 G', 851, 47, 5.33),
#  (883, 16980, 'TERRINE DE SAUMON 1.6 K', 851, 77, 10.77),
#  (884, 16981, 'TERRINE ST JACQUES 1.6 KG', 851, 77, 18.57),
#  (885, 16982, 'TERRINE DE 3 POISSONS 1.6 K', 851, 77, 11.06),
#  (886, 17480, 'CANNELLONI ITALPASTA 250 G', 887, 592, 1.29),
#  (887, 11646, 'FRITES FRAICHES 10/10 AVIKO 2.5 KG', 887, 35, 4.18),
#  (888, 17011, 'VERMICELLE DE RIZ 375G', 887, 47, 2.4),
#  (889, 17012, 'TAGLIATELLES DE RIZ 400 G - 10MM', 887, 47, 1.98),
#  (890, 17013, 'TAGLIATELLES DE RIZ 400G - 3MM', 887, 47, 1.83),
#  (891, 17014, 'TAGLIATELLES DE RIZ 375G - 1MM', 887, 47, 1.83),
#  (892, 17015, 'VERMICELLE DE RIZ 200G CHEVEUX ANGE', 887, 47, 1.35),
#  (893, 17016, 'GALETTE DE RIZ 450G - 22 CM', 887, 47, 3.58),
#  (894, 17100, 'TAGLIATELLE DALLARI - ETUI 500G', 887, 592, 2.05),
#  (895, 17105, 'TAGLIATELLE  DE CECCO - 500G', 887, 592, 3.09),
#  (896, 17106, 'PAPPARDELLE NID DECECCO ETUI 500G', 887, 592, 3.54),
#  (897, 17107, 'PACCHERI DECECCO PAQUET 500 G', 887, 592, 3.36),
#  (898, 17130, 'TAGLIATELLE OEUF 6 X 1KG BARILLA', 887, 29, 32.99),
#  (899, 17131, 'TAGLIATELLE BARILLA BTE 500 G', 887, 592, 2.28),
#  (900, 17220, 'RIZ DE CAMARGUE ETUVE 5KG', 887, 35, 10.71),
#  (901, 17240, 'RIZ INDICA 5 KG VICTORIA', 887, 35, 6.29),
#  (902, 17250, "RIZ UNCLE BEN'S SAC 5 KG", 887, 35, 19.57),
#  (903, 17251, 'RIZ THAI IMPORT - SAC 5KG', 887, 35, 9.89),
#  (904, 17253, "RIZ EXQUISOTTO BEN'S - SAC 2.5 KG", 887, 35, 13.74),
#  (905, 17255, 'QUINOA BLOND SAC 2.5 KG VIVIEN PAILLE', 887, 35, 16.05),
#  (906, 17256, 'RIZ SELECTION 3 CONTINENTS SAC 2.5KG', 887, 35, 12.35),
#  (907, 17258, 'QUINOA GOURMAND 1KG', 887, 35, 10.81),
#  (908, 17259, 'PETIT EPEAUTRE DE SAULT 5 KG (GRAINES)', 887, 35, 18.81),
#  (909, 17260, 'RIZ BASMATI VICTORIA - SAC 5KG', 887, 35, 11.92),
#  (910, 17262, 'RIZ BASMATI SAC 5KG - VIVIEN PAILLE', 887, 35, 9.01),
#  (911, 17270, 'RIZ ARBORIO 1 KG', 887, 114, 2.99),
#  (912, 17271, 'RIZ CARNAROLI 1 KG', 887, 114, 3.35),
#  (913, 17276, 'RIZ  NOIR VENERE 1KG', 887, 114, 7.52),
#  (914, 17280, 'RIZ ROND SACHET 1 KG', 887, 114, 1.44),
#  (915, 17300, 'COUSCOUS MOYEN FERRERO - SAC 5KG', 887, 35, 16.99),
#  (916, 17305, 'COUSCOUS EXTRA MOYEN  AL BADIA-SAC 5KG', 887, 35, 10.79),
#  (917, 17310, 'COUSCOUS MOYEN 500G FERRERO', 887, 47, 1.8),
#  (918, 17355, 'COUSCOUS MOYEN SAC 5KG MALIKA', 887, 35, 7.29),
#  (919, 17380, 'BOULGOUR - SAC 5KG', 887, 35, 10.85),
#  (920, 17381, 'BOULGOUR BIO - SAC 5KG - VIVIEN PAILLE', 887, 35, 22.5),
#  (921, 17400, 'SEMOULE FINE - SAC 5KG', 887, 35, 8.95),
#  (922, 17401, 'SEMOULE MOYENNE - SAC 5KG', 887, 35, 10.15),
#  (923, 17405, 'SEMOULE M/F 500G', 887, 47, 1.82),
#  (924, 17406, 'SEMOULE FINE 1KG', 887, 47, 1.2),
#  (925, 17450, 'POLENTA MOYENNE 1 KG', 887, 47, 1.12),
#  (926, 17451, 'POLENTA FINE - 1 KG VIVIEN PAILLE', 887, 47, 1.51),
#  (927, 17455, 'POLENTA PRECUITE - 500G', 887, 47, 1.0),
#  (928, 17465, 'POLENTA EXPRESS TIPIAK 2.5KG', 887, 47, 6.54),
#  (929, 17466, 'POLENTA EXPRESS TIPIAK 1 KG', 887, 47, 3.3),
#  (930, 17480, 'LASAGNE BARILLA 500G', 887, 58, 2.9),
#  (931, 17481, 'LASAGNE 1/4 GASTRO 1KG PANZANI', 887, 58, 6.19),
#  (932, 17485, 'LASAGNE 1/2 GASTRO PANZANI 3KG', 887, 58, 14.66),
#  (933, 17490, 'CANNELLONI BARILLA 250 G', 887, 592, 1.89),
#  (934, 17500, 'SPAGHETTI BARILLA 500G', 887, 58, 1.56),
#  (935, 17520, 'MACCHERONI N°44 BARILLA- PAQ 500G', 887, 592, 1.55),
#  (936, 17530, 'COQUILLETTE N°32 BARILLA- PAQ 500G', 887, 592, 1.56),
#  (937, 17539, 'FARFALLE DECECCO 500G', 887, 592, 2.79),
#  (938, 17540, 'FARFALLE BARILLA 500G', 887, 592, 1.67),
#  (939, 17541, 'FARFALLE ORO CHEF 1KG BARILLA', 887, 35, 3.23),
#  (940, 17550, 'PENNE RIGATE BARILLA 500G', 887, 592, 1.61),
#  (941, 17551, 'FUSILLI BARILLA 500G', 887, 592, 1.48),
#  (942, 17554, 'FUSILLI DECECCO 500G', 887, 592, 2.15),
#  (943, 17555, 'RIGATONI BARILLA 500G', 887, 114, 1.92),
#  (944, 17556, 'RIGATONI N° 24 DECECCO-PAQ 500G', 887, 592, 2.15),
#  (945, 17565, 'TORTIS COULEUR 2KG PANZANI', 887, 35, 5.95),
#  (946, 17570, 'FARFALLE BARILLA- SAC 5KG', 887, 35, 11.45),
#  (947, 17572, 'FUSILLI BARILLA - SAC 5KG', 887, 35, 11.48),
#  (948, 17573, 'SPAGHETTI BARILLA - SAC 5 KG', 887, 35, 11.5),
#  (949, 17574, 'PENNE RIGATE BARILLA - SAC 5KG', 887, 35, 11.65),
#  (950, 17577, 'BAVETTE (LINGUINE) BARILLA - SAC 5KG', 887, 35, 10.49),
#  (951, 17580, 'PENNE RIGATE DECECCO 500G', 887, 114, 2.15),
#  (952, 17582, 'SPAGHETTI N°12 DECECCO 500 G', 887, 114, 2.7),
#  (953, 17583, 'PENNE RIGATE DECECCO - SAC 3KG', 887, 35, 10.72),
#  (954, 17584, 'LINGUINE DECECCO-SAC 3KG', 887, 35, 10.67),
#  (955, 17586, 'FARFALLE DECECCO-SAC 3KG', 887, 35, 10.24),
#  (956, 17591, 'CANNELLONI DECECCO 250G', 887, 35, 3.41),
#  (957, 17593, 'NOUILLES CHINOISES OEUFS 454G', 887, 592, 2.56),
#  (958, 17594, 'NOUILLES CHINOISES SUZI WAN - 250G', 887, 47, 2.83),
#  (959, 17595, 'NOUILLES CHINOISES OEUFS 454G LARGE', 887, 592, 2.61),
#  (960, 17602, 'PUREE PDT FLOCON LAIT SAC 5 KG', 887, 35, 19.32),
#  (961, 17640, 'PUREE GRANULEE LAIT 800 G X 2 MOUSLINE', 887, 58, 11.39),
#  (962, 17700, 'EBLY SAC 5 KG', 887, 35, 26.38),
#  (963, 17805, 'COQUILLETTES PANZANI - 5 KG', 887, 35, 9.62),
#  (964, 17821, 'LASAGNE N°173 RUMMO 500G', 887, 592, 2.42),
#  (965, 17822, 'TAGLIATELLE  N° 36  RUMMO - CT 12X 250G', 887, 592, 1.32),
#  (966, 17824, 'PENNE RIGATE N° 66 RUMMO - SAC 3KG', 887, 35, 7.28),
#  (967, 17830, 'LINGUINE RUMMO -  SAC 1KG', 887, 47, 2.66),
#  (968, 17832, 'PENNE RIGATE RUMMO - SAC 500G', 887, 47, 1.55),
#  (969, 17835, 'PENNE RIGATE RUMMO - SAC 1KG', 887, 47, 2.51),
#  (970, 17836, 'SPAGHETTI RUMMO - SAC 1KG', 887, 47, 2.4),
#  (971, 17853, 'MEZZE RIGATONI DE CECCO - SAC 3 KG', 887, 35, 11.56),
#  (972, 17900, 'FEUILLES DE BRICK X 10', 887, 47, 1.12),
#  (973, 17905, 'PATE A FILO 500G', 887, 47, 3.75),
#  (974, 17940, 'PATE BRISEE A DEROULER', 887, 47, 0.79),
#  (975, 17941, 'PATE FEUILLETEE A DEROULER 230 G', 887, 47, 0.76),
#  (976, 17954, 'GNOCCHI PDT FRAIS - LE KG', 887, 34, 6.19),
#  (977, 17955, 'GNOCCHI À LA TRUFFE 1 KG X 5 - CARTON', 887, 29, 54.5),
#  (978, 17960, 'RAVIOLI BOEUF 1KG', 887, 47, 3.93),
#  (979, 17961, 'RAVIOLI LOUP DE MER 1 KG', 887, 49, 14.9),
#  (980, 17962, 'RAVIOLINI ARTICHAUTS SANREMO 1KG', 887, 49, 17.0),
#  (981, 17972, 'TAGLIATELLE FRAICHE 1KG', 887, 47, 3.19),
#  (982, 17973, 'PANISSE BARQ (ENV 1.8KG) - LE KG', 887, 34, 6.05),
#  (983, 17974, 'DEMI LUNE A LA RICOTTE - KG', 887, 34, 12.61),
#  (984, 17975, 'RAVIOLI AUX EPINARDS GD - LE KG', 887, 34, 12.57),
#  (985, 17976, 'TAGLIONI NATURE AUX OEUFS CIPRIANI X 12', 887, 29, 63.0),
#  (986, 17977, 'TROFIETTE CHATAIGNE 1 KG X 5', 887, 29, 29.5),
#  (987, 17986, 'GNOCCHI FRAIS S/V SACHET 500G', 887, 47, 2.38),
#  (988, 18020, 'FARINE T 55  10 X 1KG', 989, 71, 0.8),
#  (989, 18021, 'FARINE T55 SABAROT 5KG', 989, 35, 3.76),
#  (990, 18030, 'FARINE MIX TEMPURA 500 G', 989, 47, 7.1),
#  (991, 18031, 'FARINE MIX TEMPURA 150G', 989, 47, 1.95),
#  (992, 18032, 'TEMPURA 5 KG', 989, 47, 24.34),
#  (993, 18040, 'FARINE T45 JULIETTE 10 X 1 KG', 989, 71, 0.75),
#  (994, 18051, 'FARINE ITALIENNE T00/T45 SAC 5KG DALLARI', 989, 35, 4.76),
#  (995, 18053, 'FARINE STACCAPIZZA 10X1KG', 989, 71, 1.77),
#  (996, 18055, 'FARINE ITALIENNE PZ3 - SAC 5KG', 989, 35, 4.65),
#  (997, 18060, 'FARINE FLUIDE 10 X 1KG  FRANCINE', 989, 71, 1.35),
#  (998, 18090, 'FARINE BLE NOIR SARRASIN - 1 KG', 989, 47, 3.14),
#  (999, 18200, 'SAUCE BECHAMEL (BLANCHE) 2.5 KG COMPLET', 989, 47, 16.21),
#  (1000, 18201, 'SAUCE BECHAMEL KNORR 1 L BRIQUE', 989, 163, 6.99),
#  ...]
